# %% [markdown]
# ## Get data
#
# Read data from anaconda and pypi. Get package data from repodata.json
#
# ```bash
# curl https://repo.anaconda.com/pkgs/main/linux-64/repodata.json -o repodata.json
# jq -r '.packages[].name' repodata.json | uniq > anaconda.txt
# ```
#
# Used [pypinfo](https://github.com/ofek/pypinfo) to query the top 5000 pypi downloads in Google Big Query. Follow the directions to create a project on BigQuery. Note that this query is reduced to the top 1000.
#
# ```bash
# pypinfo -l 5000 -j --days 365 "" project > popular-pypi-downloads.json
# ```

# %%
import json
from operator import itemgetter

anaconda_data = open('anaconda.txt')
anaconda_pkgs = set()
for pkg in anaconda_data:
    anaconda_pkgs.add(pkg.rstrip())

pypi_data = open('popular-pypi-downloads.json')
pypi_json = json.load(pypi_data)
pypi_pkgs = set()
pypi_projects = pypi_json['rows']
pypi_top1k = pypi_projects[:1000]                          
for project in pypi_top1k:
    pypi_pkgs.add(project.get('project'))

# %% [markdown]
# ## Compare the difference

# %%
pkg_diff = sorted(pypi_pkgs.difference(anaconda_pkgs))
pkg_intersect = sorted(pypi_pkgs.intersection(anaconda_pkgs))
print('Number of Anaconda packages that are not in PyPI:\n {}'.format(len(pkg_diff)))
print('\nAnaconda packages not in PyPI:\n')
for pkg in pkg_diff:
      print(pkg)
print('\nNumber of Anaconda packages that are in PyPI:\n {}'.format(len(pkg_intersect)))
print('Anaconda packages in PyPi:\n')
for pkg in pkg_intersect:
      print(pkg)
# Out:
# Number of Anaconda packages that are not in PyPI:
#  613
#
# Anaconda packages not in PyPI:
#
# acme
# adal
# altgraph
# amqp
# analytics-python
# aniso8601
# ansible
# antlr4-python3-runtime
# apache-beam
# applicationinsights
# appnope
# apscheduler
# argh
# argparse
# aspy-yaml
# attrdict
# autobahn
# avro
# awscli
# awscli-cwlogs
# awsebcli
# azure-batch
# azure-cli-acr
# azure-cli-acs
# azure-cli-advisor
# azure-cli-appservice
# azure-cli-backup
# azure-cli-batch
# azure-cli-batchai
# azure-cli-billing
# azure-cli-cdn
# azure-cli-cloud
# azure-cli-cognitiveservices
# azure-cli-command-modules-nspkg
# azure-cli-configure
# azure-cli-consumption
# azure-cli-container
# azure-cli-core
# azure-cli-cosmosdb
# azure-cli-dla
# azure-cli-dls
# azure-cli-eventgrid
# azure-cli-extension
# azure-cli-feedback
# azure-cli-find
# azure-cli-interactive
# azure-cli-iot
# azure-cli-keyvault
# azure-cli-lab
# azure-cli-monitor
# azure-cli-network
# azure-cli-nspkg
# azure-cli-profile
# azure-cli-rdbms
# azure-cli-redis
# azure-cli-reservations
# azure-cli-resource
# azure-cli-role
# azure-cli-servicefabric
# azure-cli-sql
# azure-cli-storage
# azure-cli-telemetry
# azure-cli-vm
# azure-common
# azure-cosmosdb-nspkg
# azure-cosmosdb-table
# azure-datalake-store
# azure-eventgrid
# azure-graphrbac
# azure-keyvault
# azure-mgmt
# azure-mgmt-advisor
# azure-mgmt-applicationinsights
# azure-mgmt-authorization
# azure-mgmt-batch
# azure-mgmt-batchai
# azure-mgmt-billing
# azure-mgmt-cdn
# azure-mgmt-cognitiveservices
# azure-mgmt-commerce
# azure-mgmt-compute
# azure-mgmt-consumption
# azure-mgmt-containerinstance
# azure-mgmt-containerregistry
# azure-mgmt-containerservice
# azure-mgmt-cosmosdb
# azure-mgmt-datafactory
# azure-mgmt-datalake-analytics
# azure-mgmt-datalake-nspkg
# azure-mgmt-datalake-store
# azure-mgmt-datamigration
# azure-mgmt-devtestlabs
# azure-mgmt-dns
# azure-mgmt-eventgrid
# azure-mgmt-eventhub
# azure-mgmt-hanaonazure
# azure-mgmt-iotcentral
# azure-mgmt-iothub
# azure-mgmt-iothubprovisioningservices
# azure-mgmt-keyvault
# azure-mgmt-loganalytics
# azure-mgmt-logic
# azure-mgmt-machinelearningcompute
# azure-mgmt-managementgroups
# azure-mgmt-managementpartner
# azure-mgmt-maps
# azure-mgmt-marketplaceordering
# azure-mgmt-media
# azure-mgmt-monitor
# azure-mgmt-msi
# azure-mgmt-network
# azure-mgmt-notificationhubs
# azure-mgmt-nspkg
# azure-mgmt-policyinsights
# azure-mgmt-powerbiembedded
# azure-mgmt-rdbms
# azure-mgmt-recoveryservices
# azure-mgmt-recoveryservicesbackup
# azure-mgmt-redis
# azure-mgmt-relay
# azure-mgmt-reservations
# azure-mgmt-resource
# azure-mgmt-scheduler
# azure-mgmt-search
# azure-mgmt-servicebus
# azure-mgmt-servicefabric
# azure-mgmt-signalr
# azure-mgmt-sql
# azure-mgmt-storage
# azure-mgmt-subscription
# azure-mgmt-trafficmanager
# azure-mgmt-web
# azure-multiapi-storage
# azure-nspkg
# azure-servicebus
# azure-servicefabric
# azure-servicemanagement-legacy
# azure-storage
# azure-storage-blob
# azure-storage-common
# azure-storage-file
# azure-storage-nspkg
# azure-storage-queue
# backoff
# backports-abc
# backports-csv
# backports-functools-lru-cache
# backports-shutil-get-terminal-size
# backports-ssl-match-hostname
# backports-tempfile
# backports-weakref
# bandit
# baselines
# beautifulsoup
# behave
# billiard
# binaryornot
# black
# blessed
# blessings
# bottle
# brotlipy
# brunel
# bs4
# cachetools
# cairocffi
# cairosvg
# capstone
# cassandra-driver
# cchardet
# celery
# cement
# cerberus
# certbot
# certbot-apache
# certbot-nginx
# cfn-flip
# ciso8601
# clickclick
# cliff
# cmd2
# codecov
# collections-extended
# colorlog
# confluent-kafka
# cookiecutter
# cookiejar
# coreapi
# coreschema
# crcmod
# credstash
# croniter
# cssselect2
# cssutils
# cx-oracle
# databricks-cli
# datadog
# dateparser
# datetime
# ddt
# ddtrace
# debtcollector
# deepdiff
# deprecated
# deprecation
# dictdiffer
# diff-match-patch
# discord-py
# distro
# dj-database-url
# django-allauth
# django-appconf
# django-braces
# django-compressor
# django-cors-headers
# django-crispy-forms
# django-debug-toolbar
# django-environ
# django-extensions
# django-filter
# django-ipware
# django-model-utils
# django-nose
# django-redis
# django-rest-swagger
# django-storages
# djangorestframework
# djangorestframework-jwt
# docker
# docker-compose
# docker-pycreds
# dockerpty
# dogpile-cache
# easyprocess
# ec2-metadata
# elasticsearch-curator
# enum
# et-xmlfile
# eventlet
# expiringdict
# extras
# factory-boy
# fakeredis
# falcon
# fasteners
# filechunkio
# findspark
# fixtures
# flake8-docstrings
# flask-admin
# flask-cache
# flask-httpauth
# flask-marshmallow
# flask-migrate
# flask-restful
# flask-restplus
# flask-script
# flask-swagger
# flower
# freezegun
# fuzzywuzzy
# gapic-google-cloud-datastore-v1
# gapic-google-cloud-error-reporting-v1beta1
# gapic-google-cloud-logging-v2
# gapic-google-cloud-pubsub-v1
# gcloud
# geographiclib
# geoip2
# geojson
# geopy
# google-api-core
# google-api-python-client
# google-apitools
# google-auth
# google-auth-httplib2
# google-auth-oauthlib
# google-cloud
# google-cloud-bigquery
# google-cloud-bigquery-datatransfer
# google-cloud-bigtable
# google-cloud-container
# google-cloud-core
# google-cloud-dataflow
# google-cloud-datastore
# google-cloud-dns
# google-cloud-error-reporting
# google-cloud-firestore
# google-cloud-language
# google-cloud-logging
# google-cloud-monitoring
# google-cloud-pubsub
# google-cloud-resource-manager
# google-cloud-runtimeconfig
# google-cloud-spanner
# google-cloud-speech
# google-cloud-storage
# google-cloud-trace
# google-cloud-translate
# google-cloud-videointelligence
# google-cloud-vision
# google-compute-engine
# google-gax
# google-resumable-media
# googleads
# googleapis-common-protos
# googledatastore
# googlemaps
# graphene
# graphql-core
# graypy
# grpc-google-iam-v1
# gspread
# gym
# hacking
# hashids
# haversine
# hdfs
# hiredis
# holidays
# html2text
# httplib2
# hvac
# identify
# idna-ssl
# ijson
# importlib
# inflect
# influxdb
# initools
# ipdb
# ipython-genutils
# itypes
# jaraco-functools
# javaobj-py3
# jinja2-time
# jira
# josepy
# jpype1
# jsonfield
# jsonpatch
# jsonpath-rw
# jsonpickle
# jsonpointer
# junit-xml
# jupyter-client
# jupyter-console
# jupyter-core
# jws
# kafka-python
# kazoo
# keystoneauth1
# knack
# kombu
# kubernetes
# letsencrypt
# libtmux
# livereload
# logging
# macholib
# manhole
# maxminddb
# mleap
# mlflow
# mmh3
# mongoengine
# monotonic
# moto
# mozfile
# mozinfo
# mozlog
# mozprofile
# mozrunner
# mozterm
# mpi4py
# mrjob
# msgpack
# msrest
# msrestazure
# multi-key-dict
# multiprocess
# mypy-extensions
# mysql-connector
# mysql-python
# netaddr
# netifaces
# newrelic
# nodeenv
# nose-exclude
# nose-timer
# ntlm-auth
# nvidia-ml-py3
# oauth
# oauth2
# oauth2client
# odfpy
# openapi-codec
# opencv-python
# openstacksdk
# ordereddict
# os-client-config
# os-service-types
# osc-lib
# oslo-concurrency
# oslo-config
# oslo-context
# oslo-i18n
# oslo-log
# oslo-serialization
# oslo-utils
# package
# pager
# paho-mqtt
# pandas-gbq
# parse
# parse-type
# path-py
# pathspec
# pathtools
# pattern
# pdfminer
# pefile
# pendulum
# pg8000
# pika
# pip-lock
# pip-tools
# pipenv
# plumbum
# portalocker
# poyo
# pre-commit
# prettytable
# prometheus-client
# promise
# prompt-toolkit
# proto-google-cloud-datastore-v1
# proto-google-cloud-error-reporting-v1beta1
# proto-google-cloud-logging-v2
# proto-google-cloud-pubsub-v1
# protobuf3-to-dict
# psycopg2-binary
# ptvsd
# pulp
# pyathenajdbc
# pycountry
# pycountry-convert
# pydevd
# pydocumentdb
# pygame
# pygithub
# pygobject
# pygsheets
# pyhocon
# pyinstaller
# pyjks
# pykube
# pylint-django
# pylint-plugin-utils
# pylru
# pymemcache
# pynamodb
# pypdf2
# pyperclip
# pyphen
# pypiwin32
# pypng
# pyqt5
# pyrfc3339
# pysftp
# pysqlite
# pystache
# pytest-django
# pytest-instafail
# python-augeas
# python-cinderclient
# python-consul
# python-docx
# python-dotenv
# python-geohash
# python-glanceclient
# python-gnupg
# python-http-client
# python-jenkins
# python-json-logger
# python-jwt
# python-keystoneclient
# python-ldap
# python-levenshtein
# python-logstash
# python-magic
# python-mimeparse
# python-nmap
# python-novaclient
# python-openid
# python-openstackclient
# python-pam
# python-subunit
# python-swiftclient
# python3-openid
# pythonwhois
# pytzdata
# pyvcf
# pyvirtualdisplay
# pyvmomi
# pywin32
# pyxdg
# qds-sdk
# qrcode
# querystring-parser
# raven
# rcssmin
# readme-renderer
# recommonmark
# redis-py-cluster
# repoze-lru
# requests-aws4auth
# requests-futures
# requests-mock
# requests-ntlm
# requestsexceptions
# retry
# rfc3986
# rfc3987
# rjsmin
# robotframework
# rq
# rsa
# ruamel-ordereddict
# ruamel-yaml
# rx
# s2sphere
# s3cmd
# schedule
# schema
# semantic-version
# sendgrid
# sentry-sdk
# service-identity
# setproctitle
# shortuuid
# simple-salesforce
# simpleflock
# sklearn
# slackclient
# slacker
# slackweb
# smart-open
# snowflake-connector-python
# social-auth-app-django
# social-auth-core
# spark-sklearn
# sphinx-rtd-theme
# sqlalchemy-migrate
# sqlalchemy-redshift
# sshtunnel
# statsd
# stevedore
# strict-rfc3339
# structlog
# suds
# swagger-spec-validator
# tablib
# tenacity
# tensorflow-metadata
# tensorflow-transform
# terminaltables
# texttable
# thrift-sasl
# timeout-decorator
# tinycss2
# tldextract
# torch
# tox
# troposphere
# trueskill
# twilio
# txaio
# typing-extensions
# ua-parser
# unittest-xml-reporting
# uptime
# uritemplate
# urwid
# user-agents
# uuid
# uwsgi
# validate-email
# vine
# virtualenv-clone
# virtualenvwrapper
# voluptuous
# vsts-cd-manager
# wandb
# warlock
# watchdog
# watchtower
# weasyprint
# webapp2
# websockets
# whichcraft
# whitenoise
# win-inet-pton
# wordsegment
# xgboost
# yamllint
# youtube-dl
# zc-lockfile
# zeep
# zmq
# zope-component
# zope-deprecation
# zope-event
# zope-interface
#
# Number of Anaconda packages that are in PyPI:
#  387
# Anaconda packages in PyPi:
#
# absl-py
# aiohttp
# alabaster
# alembic
# anyjson
# apipkg
# appdirs
# argcomplete
# arrow
# asn1crypto
# astor
# astroid
# async-timeout
# asyncpg
# atomicwrites
# attrs
# automat
# autopep8
# aws-xray-sdk
# azure
# babel
# backcall
# bcrypt
# beautifulsoup4
# bitarray
# bleach
# blinker
# bokeh
# boto
# boto3
# botocore
# bz2file
# cachecontrol
# cached-property
# certifi
# cffi
# chardet
# cheetah
# cheroot
# cherrypy
# click
# click-plugins
# cligj
# cloudpickle
# colorama
# coloredlogs
# commonmark
# configargparse
# configobj
# configparser
# constantly
# contextlib2
# cookies
# coverage
# coveralls
# cryptography
# cssselect
# cvxopt
# cycler
# cymem
# cython
# cytoolz
# dask
# decorator
# defusedxml
# dicttoxml
# dill
# django
# dnspython
# docker-py
# docopt
# docutils
# ecdsa
# elasticsearch
# elasticsearch-dsl
# entrypoints
# enum34
# execnet
# fabric
# faker
# fastavro
# feedparser
# filelock
# fiona
# flake8
# flake8-import-order
# flake8-polyfill
# flaky
# flask
# flask-cors
# flask-login
# flask-sqlalchemy
# flask-wtf
# funcsigs
# functools32
# future
# futures
# gast
# gdata
# gensim
# gevent
# gitdb2
# gitpython
# glob2
# graphviz
# greenlet
# grpcio
# grpcio-tools
# gunicorn
# h5py
# html5lib
# httpretty
# humanfriendly
# humanize
# hyperlink
# hypothesis
# idna
# imageio
# imagesize
# incremental
# inflection
# intel-openmp
# invoke
# ipaddress
# ipykernel
# ipython
# ipywidgets
# iso8601
# isodate
# isort
# itsdangerous
# jdcal
# jedi
# jeepney
# jinja2
# jmespath
# joblib
# jsondiff
# jsonschema
# jupyter
# keras
# keras-applications
# keras-preprocessing
# keyring
# kiwisolver
# lazy-object-proxy
# ldap3
# lightgbm
# linecache2
# llvmlite
# lockfile
# luigi
# lxml
# mako
# markdown
# markupsafe
# marshmallow
# matplotlib
# mccabe
# meld3
# mistune
# mkl
# mock
# more-itertools
# mpmath
# msgpack-numpy
# msgpack-python
# multidict
# munch
# murmurhash
# mypy
# mysql-connector-python
# mysqlclient
# nbconvert
# nbformat
# ndg-httpsclient
# networkx
# nltk
# nose
# notebook
# numba
# numexpr
# numpy
# oauthlib
# olefile
# openpyxl
# opentracing
# packaging
# pandas
# pandocfilters
# parameterized
# paramiko
# parsedatetime
# parsel
# parso
# passlib
# paste
# pastedeploy
# pathlib
# pathlib2
# patsy
# pbr
# pep8
# pep8-naming
# pexpect
# phonenumbers
# pickleshare
# pillow
# pip
# pkginfo
# plac
# plotly
# pluggy
# ply
# portend
# preshed
# progressbar2
# protobuf
# psutil
# psycopg2
# ptyprocess
# py
# py4j
# pyaml
# pyarrow
# pyasn1
# pyasn1-modules
# pycairo
# pycodestyle
# pycparser
# pycrypto
# pycryptodome
# pycryptodomex
# pycurl
# pydispatcher
# pydocstyle
# pydot
# pyflakes
# pygments
# pyhamcrest
# pyhive
# pyinotify
# pyjwt
# pylint
# pymongo
# pympler
# pymssql
# pymysql
# pynacl
# pyodbc
# pyopenssl
# pyparsing
# pyproj
# pyrsistent
# pyserial
# pysocks
# pyspark
# pystan
# pytest
# pytest-cov
# pytest-forked
# pytest-html
# pytest-metadata
# pytest-mock
# pytest-runner
# pytest-timeout
# pytest-xdist
# python-daemon
# python-dateutil
# python-editor
# python-gflags
# python-jose
# python-memcached
# python-slugify
# python-utils
# pytimeparse
# pytz
# pywavelets
# pyyaml
# pyzmq
# qtconsole
# queuelib
# redis
# regex
# reportlab
# requests
# requests-file
# requests-oauthlib
# requests-toolbelt
# responses
# retrying
# rtree
# s3fs
# s3transfer
# sasl
# scandir
# scikit-image
# scikit-learn
# scipy
# scp
# scrapy
# seaborn
# secretstorage
# selenium
# semver
# send2trash
# setuptools
# sh
# shapely
# simplegeneric
# simplejson
# singledispatch
# six
# smmap2
# snowballstemmer
# sortedcontainers
# soupsieve
# spacy
# sphinx
# sphinxcontrib-websupport
# sqlalchemy
# sqlalchemy-utils
# sqlparse
# statistics
# statsmodels
# stripe
# subprocess32
# suds-jurko
# supervisor
# sympy
# tabulate
# tblib
# tempita
# tempora
# tensorboard
# tensorflow
# tensorflow-gpu
# tensorflow-tensorboard
# termcolor
# terminado
# testfixtures
# testpath
# testtools
# text-unidecode
# theano
# thinc
# thrift
# toml
# toolz
# torchvision
# tornado
# tqdm
# traceback2
# traitlets
# translationstring
# twine
# twisted
# twofish
# typed-ast
# typing
# tzlocal
# ujson
# unicodecsv
# unidecode
# unittest2
# urllib3
# uvloop
# virtualenv
# w3lib
# waitress
# wcwidth
# webencodings
# webob
# websocket-client
# webtest
# werkzeug
# wheel
# whoosh
# widgetsnbextension
# wrapt
# wtforms
# xlrd
# xlsxwriter
# xlwt
# xmltodict
# yapf
# yarl

# %%
missing_pkg_list = []
for pkg in pkg_diff:
    for prj in by_download_counts:
        if pkg == prj.get('project'):
            missing_pkg_list.append(prj)

by_download_counts = sorted(missing_pkg_list, key = itemgetter('download_count'), reverse=True)

for download in by_download_counts:
    print(download)
# Out:
# {'download_count': 220589827, 'project': 'awscli'}
# {'download_count': 220184575, 'project': 'rsa'}
# {'download_count': 100903711, 'project': 'awscli-cwlogs'}
# {'download_count': 47059653, 'project': 'google-api-core'}
# {'download_count': 42725585, 'project': 'argparse'}
# {'download_count': 42312992, 'project': 'google-cloud-core'}
# {'download_count': 38210088, 'project': 'cachetools'}
# {'download_count': 36510505, 'project': 'google-auth'}
# {'download_count': 35081177, 'project': 'httplib2'}
# {'download_count': 33981589, 'project': 'oauth2client'}
# {'download_count': 33693132, 'project': 'google-api-python-client'}
# {'download_count': 29790532, 'project': 'uritemplate'}
# {'download_count': 29473624, 'project': 'google-resumable-media'}
# {'download_count': 28892088, 'project': 'docker'}
# {'download_count': 28719299, 'project': 'docker-pycreds'}
# {'download_count': 28552132, 'project': 'prompt-toolkit'}
# {'download_count': 27532499, 'project': 'google-cloud-bigquery'}
# {'download_count': 26027857, 'project': 'sklearn'}
# {'download_count': 25789054, 'project': 'google-cloud-storage'}
# {'download_count': 25516828, 'project': 'pymemcache'}
# {'download_count': 25279862, 'project': 'googleapis-common-protos'}
# {'download_count': 24635836, 'project': 'backports-functools-lru-cache'}
# {'download_count': 22712990, 'project': 'ipython-genutils'}
# {'download_count': 21585703, 'project': 'google-auth-httplib2'}
# {'download_count': 19573540, 'project': 'opencv-python'}
# {'download_count': 18495467, 'project': 'trueskill'}
# {'download_count': 18352205, 'project': 'pykube'}
# {'download_count': 17740291, 'project': 'websockets'}
# {'download_count': 17522055, 'project': 'apache-beam'}
# {'download_count': 17343692, 'project': 'zope-interface'}
# {'download_count': 16884265, 'project': 'datadog'}
# {'download_count': 16655719, 'project': 'backports-ssl-match-hostname'}
# {'download_count': 16360328, 'project': 'docker-compose'}
# {'download_count': 15539007, 'project': 'raven'}
# {'download_count': 15526275, 'project': 'azure-common'}
# {'download_count': 15330460, 'project': 'discord-py'}
# {'download_count': 14996029, 'project': 'hdfs'}
# {'download_count': 14787084, 'project': 'amqp'}
# {'download_count': 14531576, 'project': 'kombu'}
# {'download_count': 14209566, 'project': 'jupyter-core'}
# {'download_count': 13951226, 'project': 'ordereddict'}
# {'download_count': 13304407, 'project': 'pypng'}
# {'download_count': 13084473, 'project': 'celery'}
# {'download_count': 13083141, 'project': 'psycopg2-binary'}
# {'download_count': 13003009, 'project': 'texttable'}
# {'download_count': 12942136, 'project': 'azure-nspkg'}
# {'download_count': 12860861, 'project': 'billiard'}
# {'download_count': 12749060, 'project': 'monotonic'}
# {'download_count': 12651697, 'project': 'hiredis'}
# {'download_count': 12401833, 'project': 'jsonpickle'}
# {'download_count': 12164633, 'project': 'prettytable'}
# {'download_count': 12152287, 'project': 'dockerpty'}
# {'download_count': 11961686, 'project': 'backports-weakref'}
# {'download_count': 11875469, 'project': 'backports-abc'}
# {'download_count': 11817445, 'project': 'ansible'}
# {'download_count': 11608768, 'project': 'croniter'}
# {'download_count': 11351025, 'project': 'msgpack'}
# {'download_count': 11006841, 'project': 'vine'}
# {'download_count': 10729406, 'project': 'google-cloud-firestore'}
# {'download_count': 10705932, 'project': 'netaddr'}
# {'download_count': 10067546, 'project': 'statsd'}
# {'download_count': 9972298, 'project': 'prometheus-client'}
# {'download_count': 9902467, 'project': 'jupyter-client'}
# {'download_count': 9868154, 'project': 'djangorestframework'}
# {'download_count': 9795768, 'project': 'google-cloud-logging'}
# {'download_count': 9213067, 'project': 'backports-shutil-get-terminal-size'}
# {'download_count': 9158976, 'project': 'tox'}
# {'download_count': 9082225, 'project': 'adal'}
# {'download_count': 8475734, 'project': 'google-cloud-datastore'}
# {'download_count': 8170624, 'project': 'smart-open'}
# {'download_count': 7994967, 'project': 'gapic-google-cloud-logging-v2'}
# {'download_count': 7974731, 'project': 'stevedore'}
# {'download_count': 7941040, 'project': 'ruamel-yaml'}
# {'download_count': 7797333, 'project': 'azure-storage-common'}
# {'download_count': 7613039, 'project': 'nvidia-ml-py3'}
# {'download_count': 7605814, 'project': 'et-xmlfile'}
# {'download_count': 7534835, 'project': 'msrest'}
# {'download_count': 7467783, 'project': 'proto-google-cloud-logging-v2'}
# {'download_count': 7416944, 'project': 'python-pam'}
# {'download_count': 7393212, 'project': 'altgraph'}
# {'download_count': 7379808, 'project': 'aniso8601'}
# {'download_count': 7371602, 'project': 'whichcraft'}
# {'download_count': 7363235, 'project': 'macholib'}
# {'download_count': 7339021, 'project': 'azure-storage-blob'}
# {'download_count': 7320177, 'project': 'binaryornot'}
# {'download_count': 7260570, 'project': 'poyo'}
# {'download_count': 7239874, 'project': 'jinja2-time'}
# {'download_count': 7237199, 'project': 'cookiecutter'}
# {'download_count': 7167209, 'project': 'manhole'}
# {'download_count': 7159125, 'project': 'google-cloud-pubsub'}
# {'download_count': 7151277, 'project': 'msrestazure'}
# {'download_count': 7023213, 'project': 'python-magic'}
# {'download_count': 7020869, 'project': 'netifaces'}
# {'download_count': 6923625, 'project': 'google-auth-oauthlib'}
# {'download_count': 6903217, 'project': 'pyhocon'}
# {'download_count': 6891186, 'project': 'jupyter-console'}
# {'download_count': 6860107, 'project': 'virtualenv-clone'}
# {'download_count': 6831954, 'project': 'grpc-google-iam-v1'}
# {'download_count': 6799154, 'project': 'uwsgi'}
# {'download_count': 6706108, 'project': 'ijson'}
# {'download_count': 6680408, 'project': 'google-gax'}
# {'download_count': 6663559, 'project': 'ua-parser'}
# {'download_count': 6661355, 'project': 'xgboost'}
# {'download_count': 6652973, 'project': 'ptvsd'}
# {'download_count': 6468921, 'project': 'pydevd'}
# {'download_count': 6304159, 'project': 'azure-storage'}
# {'download_count': 6275700, 'project': 'capstone'}
# {'download_count': 6212258, 'project': 'pager'}
# {'download_count': 6200964, 'project': 'bs4'}
# {'download_count': 6044556, 'project': 'cookiejar'}
# {'download_count': 6003017, 'project': 'fuzzywuzzy'}
# {'download_count': 5971076, 'project': 'oauth'}
# {'download_count': 5820101, 'project': 'pipenv'}
# {'download_count': 5751306, 'project': 'slackclient'}
# {'download_count': 5719985, 'project': 'snowflake-connector-python'}
# {'download_count': 5686758, 'project': 'applicationinsights'}
# {'download_count': 5650630, 'project': 'newrelic'}
# {'download_count': 5415924, 'project': 'pathspec'}
# {'download_count': 5402699, 'project': 'azure-mgmt-resource'}
# {'download_count': 5388560, 'project': 'django-extensions'}
# {'download_count': 5337655, 'project': 'service-identity'}
# {'download_count': 5312723, 'project': 'azure-storage-nspkg'}
# {'download_count': 5213055, 'project': 'gym'}
# {'download_count': 5188814, 'project': 'azure-mgmt-storage'}
# {'download_count': 5178760, 'project': 'fasteners'}
# {'download_count': 5170563, 'project': 'django-filter'}
# {'download_count': 5122096, 'project': 'azure-mgmt-nspkg'}
# {'download_count': 5118360, 'project': 'gspread'}
# {'download_count': 5089807, 'project': 'google-cloud-bigtable'}
# {'download_count': 5080884, 'project': 'package'}
# {'download_count': 5076534, 'project': 'mysql-python'}
# {'download_count': 5014370, 'project': 'pika'}
# {'download_count': 5006396, 'project': 'django-cors-headers'}
# {'download_count': 4934052, 'project': 'codecov'}
# {'download_count': 4884670, 'project': 'pyrfc3339'}
# {'download_count': 4843301, 'project': 'tenacity'}
# {'download_count': 4815698, 'project': 'google-cloud-vision'}
# {'download_count': 4733113, 'project': 'geopy'}
# {'download_count': 4728088, 'project': 'freezegun'}
# {'download_count': 4707675, 'project': 'python-mimeparse'}
# {'download_count': 4689380, 'project': 'watchdog'}
# {'download_count': 4678233, 'project': 'django-storages'}
# {'download_count': 4550136, 'project': 'flask-restful'}
# {'download_count': 4523298, 'project': 'zope-event'}
# {'download_count': 4513364, 'project': 'zope-component'}
# {'download_count': 4496402, 'project': 'jaraco-functools'}
# {'download_count': 4475136, 'project': 'google-cloud-monitoring'}
# {'download_count': 4474854, 'project': 'azure-mgmt-containerregistry'}
# {'download_count': 4442754, 'project': 'voluptuous'}
# {'download_count': 4440428, 'project': 'maxminddb'}
# {'download_count': 4434142, 'project': 'kubernetes'}
# {'download_count': 4430810, 'project': 'bottle'}
# {'download_count': 4427646, 'project': 'user-agents'}
# {'download_count': 4396205, 'project': 'azure-mgmt-authorization'}
# {'download_count': 4394845, 'project': 'argh'}
# {'download_count': 4351750, 'project': 'sphinx-rtd-theme'}
# {'download_count': 4338711, 'project': 'factory-boy'}
# {'download_count': 4319843, 'project': 'azure-mgmt-compute'}
# {'download_count': 4307873, 'project': 's3cmd'}
# {'download_count': 4287253, 'project': 'azure-mgmt-network'}
# {'download_count': 4276754, 'project': 'azure-mgmt-keyvault'}
# {'download_count': 4276062, 'project': 'josepy'}
# {'download_count': 4273807, 'project': 'zc-lockfile'}
# {'download_count': 4261354, 'project': 'python-levenshtein'}
# {'download_count': 4258910, 'project': 'django-debug-toolbar'}
# {'download_count': 4254043, 'project': 'tldextract'}
# {'download_count': 4198728, 'project': 'azure-datalake-store'}
# {'download_count': 4197376, 'project': 'gapic-google-cloud-datastore-v1'}
# {'download_count': 4169294, 'project': 'python-augeas'}
# {'download_count': 4159962, 'project': 'backoff'}
# {'download_count': 4147548, 'project': 'google-cloud-spanner'}
# {'download_count': 4134847, 'project': 'acme'}
# {'download_count': 4131206, 'project': 'google-cloud'}
# {'download_count': 4130248, 'project': 'kazoo'}
# {'download_count': 4111765, 'project': 'geoip2'}
# {'download_count': 4104229, 'project': 'deepdiff'}
# {'download_count': 4088276, 'project': 'pystache'}
# {'download_count': 4087336, 'project': 'certbot'}
# {'download_count': 4078358, 'project': 'repoze-lru'}
# {'download_count': 4073112, 'project': 'avro'}
# {'download_count': 3951429, 'project': 'google-cloud-language'}
# {'download_count': 3923281, 'project': 'pathtools'}
# {'download_count': 3910855, 'project': 'letsencrypt'}
# {'download_count': 3891802, 'project': 'jws'}
# {'download_count': 3891733, 'project': 'certbot-apache'}
# {'download_count': 3872616, 'project': 'google-cloud-translate'}
# {'download_count': 3857992, 'project': 'requests-mock'}
# {'download_count': 3829162, 'project': 'python-dotenv'}
# {'download_count': 3828543, 'project': 'google-cloud-speech'}
# {'download_count': 3790403, 'project': 'python-jwt'}
# {'download_count': 3782966, 'project': 'jsonpointer'}
# {'download_count': 3774863, 'project': 'google-apitools'}
# {'download_count': 3761532, 'project': 'cassandra-driver'}
# {'download_count': 3705439, 'project': 'google-cloud-error-reporting'}
# {'download_count': 3688413, 'project': 'certbot-nginx'}
# {'download_count': 3631651, 'project': 'google-cloud-resource-manager'}
# {'download_count': 3622578, 'project': 'pyperclip'}
# {'download_count': 3620639, 'project': 'google-cloud-dns'}
# {'download_count': 3614866, 'project': 'oslo-i18n'}
# {'download_count': 3601392, 'project': 'google-cloud-runtimeconfig'}
# {'download_count': 3584230, 'project': 'geographiclib'}
# {'download_count': 3581049, 'project': 'oslo-utils'}
# {'download_count': 3570074, 'project': 'django-environ'}
# {'download_count': 3562850, 'project': 'azure-graphrbac'}
# {'download_count': 3557688, 'project': 'pip-tools'}
# {'download_count': 3527246, 'project': 'debtcollector'}
# {'download_count': 3505246, 'project': 'azure-mgmt-rdbms'}
# {'download_count': 3492258, 'project': 'google-cloud-videointelligence'}
# {'download_count': 3483685, 'project': 'azure-mgmt-dns'}
# {'download_count': 3477267, 'project': 'ipdb'}
# {'download_count': 3467651, 'project': 'pysftp'}
# {'download_count': 3465312, 'project': 'paho-mqtt'}
# {'download_count': 3460488, 'project': 'pendulum'}
# {'download_count': 3451083, 'project': 'python-json-logger'}
# {'download_count': 3447010, 'project': 'requests-aws4auth'}
# {'download_count': 3406600, 'project': 'oslo-config'}
# {'download_count': 3399501, 'project': 'azure-keyvault'}
# {'download_count': 3392196, 'project': 'dictdiffer'}
# {'download_count': 3380428, 'project': 'pytzdata'}
# {'download_count': 3373743, 'project': 'jpype1'}
# {'download_count': 3370839, 'project': 'jira'}
# {'download_count': 3355087, 'project': 'libtmux'}
# {'download_count': 3344808, 'project': 'coreapi'}
# {'download_count': 3341487, 'project': 'dogpile-cache'}
# {'download_count': 3333397, 'project': 'semantic-version'}
# {'download_count': 3333120, 'project': 'pycountry'}
# {'download_count': 3303506, 'project': 'kafka-python'}
# {'download_count': 3300196, 'project': 'zeep'}
# {'download_count': 3295665, 'project': 'rfc3986'}
# {'download_count': 3295339, 'project': 'retry'}
# {'download_count': 3287026, 'project': 'coreschema'}
# {'download_count': 3280425, 'project': 'eventlet'}
# {'download_count': 3265544, 'project': 'itypes'}
# {'download_count': 3242043, 'project': 'pytest-django'}
# {'download_count': 3230346, 'project': 'oslo-serialization'}
# {'download_count': 3230058, 'project': 'idna-ssl'}
# {'download_count': 3209749, 'project': 'moto'}
# {'download_count': 3209575, 'project': 'azure-mgmt-containerinstance'}
# {'download_count': 3156115, 'project': 'graphql-core'}
# {'download_count': 3151964, 'project': 'enum'}
# {'download_count': 3133888, 'project': 'parse'}
# {'download_count': 3093469, 'project': 'jsonpatch'}
# {'download_count': 3092444, 'project': 'colorlog'}
# {'download_count': 3062699, 'project': 'azure-mgmt-containerservice'}
# {'download_count': 3056603, 'project': 'blessings'}
# {'download_count': 3049786, 'project': 'qds-sdk'}
# {'download_count': 3012131, 'project': 'gapic-google-cloud-error-reporting-v1beta1'}
# {'download_count': 3004205, 'project': 'proto-google-cloud-error-reporting-v1beta1'}
# {'download_count': 2973245, 'project': 'zope-deprecation'}
# {'download_count': 2957248, 'project': 'influxdb'}
# {'download_count': 2943662, 'project': 'azure-mgmt-batch'}
# {'download_count': 2942200, 'project': 'cmd2'}
# {'download_count': 2929434, 'project': 'extras'}
# {'download_count': 2924327, 'project': 'python-geohash'}
# {'download_count': 2923997, 'project': 'keystoneauth1'}
# {'download_count': 2923685, 'project': 'setproctitle'}
# {'download_count': 2922775, 'project': 'pypdf2'}
# {'download_count': 2906344, 'project': 'django-redis'}
# {'download_count': 2885130, 'project': 'azure-cli-core'}
# {'download_count': 2852545, 'project': 'azure-batch'}
# {'download_count': 2850661, 'project': 'python-jenkins'}
# {'download_count': 2834282, 'project': 'google-cloud-trace'}
# {'download_count': 2832236, 'project': 'requests-futures'}
# {'download_count': 2826212, 'project': 'cliff'}
# {'download_count': 2825153, 'project': 'proto-google-cloud-datastore-v1'}
# {'download_count': 2821412, 'project': 'fixtures'}
# {'download_count': 2820570, 'project': 'azure-mgmt-batchai'}
# {'download_count': 2815600, 'project': 'azure-mgmt-reservations'}
# {'download_count': 2812535, 'project': 'azure-mgmt-msi'}
# {'download_count': 2806830, 'project': 'tensorflow-metadata'}
# {'download_count': 2788463, 'project': 'haversine'}
# {'download_count': 2777592, 'project': 'azure-mgmt-datalake-store'}
# {'download_count': 2765141, 'project': 'azure-mgmt-datalake-nspkg'}
# {'download_count': 2758841, 'project': 'flask-migrate'}
# {'download_count': 2757081, 'project': 'django-appconf'}
# {'download_count': 2756343, 'project': 'azure-mgmt-loganalytics'}
# {'download_count': 2754882, 'project': 'knack'}
# {'download_count': 2732136, 'project': 'flask-restplus'}
# {'download_count': 2710574, 'project': 'azure-mgmt-web'}
# {'download_count': 2706979, 'project': 'wandb'}
# {'download_count': 2705575, 'project': 'simple-salesforce'}
# {'download_count': 2704122, 'project': 'pycountry-convert'}
# {'download_count': 2697121, 'project': 'google-cloud-container'}
# {'download_count': 2677034, 'project': 'flask-script'}
# {'download_count': 2667899, 'project': 'azure-mgmt-sql'}
# {'download_count': 2664779, 'project': 'azure-mgmt-cdn'}
# {'download_count': 2653020, 'project': 'datetime'}
# {'download_count': 2635086, 'project': 'python-consul'}
# {'download_count': 2625749, 'project': 'google-cloud-bigquery-datatransfer'}
# {'download_count': 2610693, 'project': 'twilio'}
# {'download_count': 2598661, 'project': 'yamllint'}
# {'download_count': 2571522, 'project': 'portalocker'}
# {'download_count': 2567441, 'project': 'azure-mgmt-redis'}
# {'download_count': 2558687, 'project': 'ruamel-ordereddict'}
# {'download_count': 2549274, 'project': 'strict-rfc3339'}
# {'download_count': 2532320, 'project': 'dateparser'}
# {'download_count': 2506168, 'project': 'azure-mgmt-monitor'}
# {'download_count': 2491074, 'project': 'whitenoise'}
# {'download_count': 2485694, 'project': 'pulp'}
# {'download_count': 2463646, 'project': 'azure-mgmt-cognitiveservices'}
# {'download_count': 2461393, 'project': 'azure-servicebus'}
# {'download_count': 2444617, 'project': 'azure-cli-nspkg'}
# {'download_count': 2441411, 'project': 'azure-mgmt-trafficmanager'}
# {'download_count': 2437567, 'project': 'dj-database-url'}
# {'download_count': 2411258, 'project': 'multi-key-dict'}
# {'download_count': 2407317, 'project': 'pyathenajdbc'}
# {'download_count': 2403335, 'project': 'slacker'}
# {'download_count': 2384448, 'project': 'pypiwin32'}
# {'download_count': 2381685, 'project': 'backports-tempfile'}
# {'download_count': 2371949, 'project': 'pandas-gbq'}
# {'download_count': 2367062, 'project': 'flower'}
# {'download_count': 2364749, 'project': 'schedule'}
# {'download_count': 2363461, 'project': 'crcmod'}
# {'download_count': 2357447, 'project': 'html2text'}
# {'download_count': 2350156, 'project': 'zmq'}
# {'download_count': 2343228, 'project': 'pywin32'}
# {'download_count': 2339529, 'project': 'youtube-dl'}
# {'download_count': 2334130, 'project': 'azure-mgmt-cosmosdb'}
# {'download_count': 2313187, 'project': 'thrift-sasl'}
# {'download_count': 2309607, 'project': 'python-keystoneclient'}
# {'download_count': 2296608, 'project': 'promise'}
# {'download_count': 2283533, 'project': 'pdfminer'}
# {'download_count': 2273996, 'project': 'python-subunit'}
# {'download_count': 2265132, 'project': 'azure-mgmt-devtestlabs'}
# {'download_count': 2261937, 'project': 'azure-mgmt-iothub'}
# {'download_count': 2256930, 'project': 'azure-mgmt-datalake-analytics'}
# {'download_count': 2253692, 'project': 'mypy-extensions'}
# {'download_count': 2246434, 'project': 'google-compute-engine'}
# {'download_count': 2245924, 'project': 'openstacksdk'}
# {'download_count': 2241091, 'project': 'nose-exclude'}
# {'download_count': 2233043, 'project': 'azure-cli-profile'}
# {'download_count': 2225194, 'project': 'parse-type'}
# {'download_count': 2223865, 'project': 'beautifulsoup'}
# {'download_count': 2222493, 'project': 'hvac'}
# {'download_count': 2214937, 'project': 'sendgrid'}
# {'download_count': 2207952, 'project': 'pytest-instafail'}
# {'download_count': 2207310, 'project': 'azure-cli-command-modules-nspkg'}
# {'download_count': 2197432, 'project': 'robotframework'}
# {'download_count': 2195547, 'project': 'os-service-types'}
# {'download_count': 2191117, 'project': 'cx-oracle'}
# {'download_count': 2175905, 'project': 'sentry-sdk'}
# {'download_count': 2172946, 'project': 'swagger-spec-validator'}
# {'download_count': 2166432, 'project': 'easyprocess'}
# {'download_count': 2162832, 'project': 'credstash'}
# {'download_count': 2161580, 'project': 'torch'}
# {'download_count': 2158882, 'project': 'python3-openid'}
# {'download_count': 2158371, 'project': 'redis-py-cluster'}
# {'download_count': 2157760, 'project': 'pyvmomi'}
# {'download_count': 2135706, 'project': 'graypy'}
# {'download_count': 2128174, 'project': 'simpleflock'}
# {'download_count': 2126917, 'project': 'baselines'}
# {'download_count': 2116189, 'project': 'azure-mgmt-iothubprovisioningservices'}
# {'download_count': 2109904, 'project': 'sshtunnel'}
# {'download_count': 2109681, 'project': 'apscheduler'}
# {'download_count': 2108938, 'project': 'azure-mgmt-servicefabric'}
# {'download_count': 2094650, 'project': 'deprecation'}
# {'download_count': 2093109, 'project': 'azure-servicemanagement-legacy'}
# {'download_count': 2088359, 'project': 'pip-lock'}
# {'download_count': 2086936, 'project': 'python-ldap'}
# {'download_count': 2085747, 'project': 'terminaltables'}
# {'download_count': 2084496, 'project': 'azure-cli-telemetry'}
# {'download_count': 2083882, 'project': 'backports-csv'}
# {'download_count': 2080191, 'project': 'pygithub'}
# {'download_count': 2078796, 'project': 'openapi-codec'}
# {'download_count': 2055741, 'project': 'pydocumentdb'}
# {'download_count': 2048889, 'project': 's2sphere'}
# {'download_count': 2048014, 'project': 'azure-mgmt'}
# {'download_count': 2042067, 'project': 'azure-mgmt-eventhub'}
# {'download_count': 2040620, 'project': 'azure-mgmt-marketplaceordering'}
# {'download_count': 2023669, 'project': 'findspark'}
# {'download_count': 2004886, 'project': 'python-docx'}
# {'download_count': 2002192, 'project': 'azure-mgmt-eventgrid'}
# {'download_count': 1992616, 'project': 'azure-mgmt-recoveryservices'}
# {'download_count': 1986421, 'project': 'mmh3'}
# {'download_count': 1984464, 'project': 'azure-mgmt-consumption'}
# {'download_count': 1984057, 'project': 'azure-mgmt-billing'}
# {'download_count': 1983975, 'project': 'azure-mgmt-recoveryservicesbackup'}
# {'download_count': 1982874, 'project': 'azure-mgmt-advisor'}
# {'download_count': 1980297, 'project': 'azure-cli-resource'}
# {'download_count': 1979746, 'project': 'behave'}
# {'download_count': 1968106, 'project': 'azure-cli-interactive'}
# {'download_count': 1966287, 'project': 'azure-cli-acs'}
# {'download_count': 1965908, 'project': 'azure-cli-sql'}
# {'download_count': 1964755, 'project': 'azure-cli-network'}
# {'download_count': 1964412, 'project': 'azure-cli-storage'}
# {'download_count': 1963351, 'project': 'azure-mgmt-servicebus'}
# {'download_count': 1960471, 'project': 'azure-cli-vm'}
# {'download_count': 1957758, 'project': 'azure-cli-acr'}
# {'download_count': 1956248, 'project': 'mysql-connector'}
# {'download_count': 1953597, 'project': 'azure-cli-iot'}
# {'download_count': 1953342, 'project': 'appnope'}
# {'download_count': 1953006, 'project': 'googleads'}
# {'download_count': 1949865, 'project': 'databricks-cli'}
# {'download_count': 1948991, 'project': 'filechunkio'}
# {'download_count': 1948184, 'project': 'gcloud'}
# {'download_count': 1944688, 'project': 'azure-cli-batch'}
# {'download_count': 1935724, 'project': 'unittest-xml-reporting'}
# {'download_count': 1932314, 'project': 'django-model-utils'}
# {'download_count': 1930909, 'project': 'pattern'}
# {'download_count': 1919509, 'project': 'azure-mgmt-media'}
# {'download_count': 1913939, 'project': 'requestsexceptions'}
# {'download_count': 1907231, 'project': 'pysqlite'}
# {'download_count': 1905935, 'project': 'python-nmap'}
# {'download_count': 1888735, 'project': 'cairocffi'}
# {'download_count': 1873688, 'project': 'python-novaclient'}
# {'download_count': 1873571, 'project': 'brotlipy'}
# {'download_count': 1861793, 'project': 'distro'}
# {'download_count': 1858657, 'project': 'expiringdict'}
# {'download_count': 1848623, 'project': 'pefile'}
# {'download_count': 1845397, 'project': 'flask-admin'}
# {'download_count': 1822531, 'project': 'azure-mgmt-search'}
# {'download_count': 1820382, 'project': 'bandit'}
# {'download_count': 1816725, 'project': 'hashids'}
# {'download_count': 1814338, 'project': 'azure-mgmt-logic'}
# {'download_count': 1813992, 'project': 'django-rest-swagger'}
# {'download_count': 1812286, 'project': 'azure-mgmt-scheduler'}
# {'download_count': 1808438, 'project': 'multiprocess'}
# {'download_count': 1797667, 'project': 'cssutils'}
# {'download_count': 1796557, 'project': 'azure-cli-extension'}
# {'download_count': 1793758, 'project': 'os-client-config'}
# {'download_count': 1787755, 'project': 'azure-cli-role'}
# {'download_count': 1787477, 'project': 'azure-cli-container'}
# {'download_count': 1786281, 'project': 'azure-cli-appservice'}
# {'download_count': 1785433, 'project': 'azure-cli-rdbms'}
# {'download_count': 1785098, 'project': 'azure-cli-monitor'}
# {'download_count': 1779483, 'project': 'azure-cli-dla'}
# {'download_count': 1779129, 'project': 'azure-cli-keyvault'}
# {'download_count': 1776635, 'project': 'azure-cli-batchai'}
# {'download_count': 1775259, 'project': 'azure-cli-dls'}
# {'download_count': 1769569, 'project': 'azure-cli-lab'}
# {'download_count': 1768233, 'project': 'mozlog'}
# {'download_count': 1765517, 'project': 'python-http-client'}
# {'download_count': 1763076, 'project': 'azure-cli-cognitiveservices'}
# {'download_count': 1762764, 'project': 'azure-cli-cdn'}
# {'download_count': 1761182, 'project': 'cairosvg'}
# {'download_count': 1760033, 'project': 'azure-cli-cosmosdb'}
# {'download_count': 1759748, 'project': 'python-swiftclient'}
# {'download_count': 1758317, 'project': 'azure-cli-servicefabric'}
# {'download_count': 1756209, 'project': 'azure-cli-reservations'}
# {'download_count': 1754054, 'project': 'qrcode'}
# {'download_count': 1734011, 'project': 'tensorflow-transform'}
# {'download_count': 1731595, 'project': 'pyvirtualdisplay'}
# {'download_count': 1726499, 'project': 'osc-lib'}
# {'download_count': 1726197, 'project': 'azure-mgmt-managementgroups'}
# {'download_count': 1718044, 'project': 'inflect'}
# {'download_count': 1717710, 'project': 'geojson'}
# {'download_count': 1709847, 'project': 'typing-extensions'}
# {'download_count': 1707399, 'project': 'jsonfield'}
# {'download_count': 1702162, 'project': 'uuid'}
# {'download_count': 1696826, 'project': 'ec2-metadata'}
# {'download_count': 1686584, 'project': 'azure-mgmt-datamigration'}
# {'download_count': 1682510, 'project': 'azure-mgmt-relay'}
# {'download_count': 1673420, 'project': 'jsonpath-rw'}
# {'download_count': 1668830, 'project': 'blessed'}
# {'download_count': 1664437, 'project': 'structlog'}
# {'download_count': 1662500, 'project': 'oslo-log'}
# {'download_count': 1660464, 'project': 'protobuf3-to-dict'}
# {'download_count': 1660208, 'project': 'collections-extended'}
# {'download_count': 1647263, 'project': 'importlib'}
# {'download_count': 1642703, 'project': 'cerberus'}
# {'download_count': 1641771, 'project': 'nodeenv'}
# {'download_count': 1637269, 'project': 'cement'}
# {'download_count': 1634961, 'project': 'watchtower'}
# {'download_count': 1626983, 'project': 'mpi4py'}
# {'download_count': 1614628, 'project': 'azure-cosmosdb-table'}
# {'download_count': 1601807, 'project': 'djangorestframework-jwt'}
# {'download_count': 1591673, 'project': 'rx'}
# {'download_count': 1588322, 'project': 'google-cloud-dataflow'}
# {'download_count': 1581446, 'project': 'python-logstash'}
# {'download_count': 1571235, 'project': 'python-glanceclient'}
# {'download_count': 1570054, 'project': 'pyxdg'}
# {'download_count': 1569548, 'project': 'azure-multiapi-storage'}
# {'download_count': 1568416, 'project': 'pygobject'}
# {'download_count': 1563211, 'project': 'vsts-cd-manager'}
# {'download_count': 1559784, 'project': 'analytics-python'}
# {'download_count': 1558927, 'project': 'win-inet-pton'}
# {'download_count': 1558750, 'project': 'azure-cli-configure'}
# {'download_count': 1557846, 'project': 'oslo-context'}
# {'download_count': 1556298, 'project': 'azure-cli-cloud'}
# {'download_count': 1555694, 'project': 'confluent-kafka'}
# {'download_count': 1554770, 'project': 'django-nose'}
# {'download_count': 1552207, 'project': 'pynamodb'}
# {'download_count': 1551913, 'project': 'slackweb'}
# {'download_count': 1550457, 'project': 'azure-cosmosdb-nspkg'}
# {'download_count': 1548037, 'project': 'azure-cli-backup'}
# {'download_count': 1547081, 'project': 'odfpy'}
# {'download_count': 1542893, 'project': 'azure-cli-redis'}
# {'download_count': 1542490, 'project': 'azure-cli-feedback'}
# {'download_count': 1542343, 'project': 'azure-cli-find'}
# {'download_count': 1541358, 'project': 'azure-cli-consumption'}
# {'download_count': 1540105, 'project': 'azure-cli-billing'}
# {'download_count': 1537412, 'project': 'azure-cli-advisor'}
# {'download_count': 1537146, 'project': 'azure-cli-eventgrid'}
# {'download_count': 1536534, 'project': 'tinycss2'}
# {'download_count': 1534785, 'project': 'brunel'}
# {'download_count': 1524260, 'project': 'azure-mgmt-notificationhubs'}
# {'download_count': 1521141, 'project': 'django-crispy-forms'}
# {'download_count': 1518004, 'project': 'tablib'}
# {'download_count': 1514871, 'project': 'pythonwhois'}
# {'download_count': 1514237, 'project': 'pygsheets'}
# {'download_count': 1507493, 'project': 'shortuuid'}
# {'download_count': 1503846, 'project': 'antlr4-python3-runtime'}
# {'download_count': 1493785, 'project': 'mleap'}
# {'download_count': 1492966, 'project': 'validate-email'}
# {'download_count': 1491803, 'project': 'mongoengine'}
# {'download_count': 1491618, 'project': 'azure-storage-queue'}
# {'download_count': 1490980, 'project': 'rjsmin'}
# {'download_count': 1484268, 'project': 'ddt'}
# {'download_count': 1482588, 'project': 'azure-mgmt-iotcentral'}
# {'download_count': 1482538, 'project': 'wordsegment'}
# {'download_count': 1481629, 'project': 'black'}
# {'download_count': 1480038, 'project': 'azure-mgmt-policyinsights'}
# {'download_count': 1479609, 'project': 'python-cinderclient'}
# {'download_count': 1478181, 'project': 'awsebcli'}
# {'download_count': 1476598, 'project': 'azure-mgmt-maps'}
# {'download_count': 1474797, 'project': 'azure-mgmt-signalr'}
# {'download_count': 1469132, 'project': 'rq'}
# {'download_count': 1465706, 'project': 'azure-servicefabric'}
# {'download_count': 1458362, 'project': 'autobahn'}
# {'download_count': 1452279, 'project': 'pylru'}
# {'download_count': 1449401, 'project': 'pylint-plugin-utils'}
# {'download_count': 1446803, 'project': 'pyphen'}
# {'download_count': 1444533, 'project': 'rfc3987'}
# {'download_count': 1434685, 'project': 'javaobj-py3'}
# {'download_count': 1433946, 'project': 'path-py'}
# {'download_count': 1432595, 'project': 'initools'}
# {'download_count': 1432180, 'project': 'flask-httpauth'}
# {'download_count': 1427417, 'project': 'python-openid'}
# {'download_count': 1427344, 'project': 'pyjks'}
# {'download_count': 1420374, 'project': 'googlemaps'}
# {'download_count': 1417637, 'project': 'django-compressor'}
# {'download_count': 1413738, 'project': 'fakeredis'}
# {'download_count': 1406118, 'project': 'azure-eventgrid'}
# {'download_count': 1398686, 'project': 'elasticsearch-curator'}
# {'download_count': 1398289, 'project': 'querystring-parser'}
# {'download_count': 1397753, 'project': 'warlock'}
# {'download_count': 1396980, 'project': 'azure-storage-file'}
# {'download_count': 1394813, 'project': 'urwid'}
# {'download_count': 1391123, 'project': 'nose-timer'}
# {'download_count': 1389236, 'project': 'ciso8601'}
# {'download_count': 1382274, 'project': 'pygame'}
# {'download_count': 1381828, 'project': 'azure-mgmt-applicationinsights'}
# {'download_count': 1381141, 'project': 'pyvcf'}
# {'download_count': 1375791, 'project': 'txaio'}
# {'download_count': 1364719, 'project': 'livereload'}
# {'download_count': 1359277, 'project': 'mozinfo'}
# {'download_count': 1357340, 'project': 'flask-cache'}
# {'download_count': 1354421, 'project': 'cchardet'}
# {'download_count': 1353738, 'project': 'sqlalchemy-migrate'}
# {'download_count': 1352958, 'project': 'cssselect2'}
# {'download_count': 1352946, 'project': 'mrjob'}
# {'download_count': 1349800, 'project': 'recommonmark'}
# {'download_count': 1348367, 'project': 'junit-xml'}
# {'download_count': 1344770, 'project': 'clickclick'}
# {'download_count': 1340096, 'project': 'logging'}
# {'download_count': 1338535, 'project': 'flake8-docstrings'}
# {'download_count': 1332292, 'project': 'virtualenvwrapper'}
# {'download_count': 1332153, 'project': 'uptime'}
# {'download_count': 1327968, 'project': 'mozfile'}
# {'download_count': 1327187, 'project': 'diff-match-patch'}
# {'download_count': 1321599, 'project': 'plumbum'}
# {'download_count': 1319890, 'project': 'ddtrace'}
# {'download_count': 1319637, 'project': 'gapic-google-cloud-pubsub-v1'}
# {'download_count': 1318997, 'project': 'proto-google-cloud-pubsub-v1'}
# {'download_count': 1318231, 'project': 'spark-sklearn'}
# {'download_count': 1318092, 'project': 'googledatastore'}
# {'download_count': 1315653, 'project': 'django-ipware'}
# {'download_count': 1314603, 'project': 'timeout-decorator'}
# {'download_count': 1312733, 'project': 'pg8000'}
# {'download_count': 1306566, 'project': 'webapp2'}
# {'download_count': 1304086, 'project': 'python-openstackclient'}
# {'download_count': 1303401, 'project': 'suds'}
# {'download_count': 1302666, 'project': 'azure-mgmt-datafactory'}
# {'download_count': 1301254, 'project': 'mozterm'}
# {'download_count': 1296817, 'project': 'falcon'}
# {'download_count': 1289949, 'project': 'pre-commit'}
# {'download_count': 1288753, 'project': 'oauth2'}
# {'download_count': 1288423, 'project': 'azure-mgmt-subscription'}
# {'download_count': 1288320, 'project': 'readme-renderer'}
# {'download_count': 1287809, 'project': 'oslo-concurrency'}
# {'download_count': 1287733, 'project': 'social-auth-core'}
# {'download_count': 1283243, 'project': 'python-gnupg'}
# {'download_count': 1282348, 'project': 'aspy-yaml'}
# {'download_count': 1282117, 'project': 'requests-ntlm'}
# {'download_count': 1279952, 'project': 'graphene'}
# {'download_count': 1276782, 'project': 'mozrunner'}
# {'download_count': 1274623, 'project': 'azure-mgmt-powerbiembedded'}
# {'download_count': 1268043, 'project': 'schema'}
# {'download_count': 1267633, 'project': 'pyinstaller'}
# {'download_count': 1265511, 'project': 'azure-mgmt-commerce'}
# {'download_count': 1265286, 'project': 'mozprofile'}
# {'download_count': 1262054, 'project': 'sqlalchemy-redshift'}
# {'download_count': 1261135, 'project': 'azure-mgmt-machinelearningcompute'}
# {'download_count': 1259174, 'project': 'hacking'}
# {'download_count': 1257828, 'project': 'mlflow'}
# {'download_count': 1257174, 'project': 'azure-mgmt-hanaonazure'}
# {'download_count': 1256223, 'project': 'flask-swagger'}
# {'download_count': 1256089, 'project': 'cfn-flip'}
# {'download_count': 1254055, 'project': 'attrdict'}
# {'download_count': 1251647, 'project': 'identify'}
# {'download_count': 1249714, 'project': 'social-auth-app-django'}
# {'download_count': 1246507, 'project': 'weasyprint'}
# {'download_count': 1239808, 'project': 'azure-mgmt-managementpartner'}
# {'download_count': 1238927, 'project': 'django-allauth'}
# {'download_count': 1238853, 'project': 'troposphere'}
# {'download_count': 1236786, 'project': 'pylint-django'}
# {'download_count': 1234714, 'project': 'holidays'}
# {'download_count': 1230158, 'project': 'django-braces'}
# {'download_count': 1219958, 'project': 'rcssmin'}
# {'download_count': 1214330, 'project': 'ntlm-auth'}
# {'download_count': 1214061, 'project': 'pyqt5'}
# {'download_count': 1212220, 'project': 'deprecated'}

# %% [markdown]
# ## Calculate total downloads

# %%
download_total = 0
for pkg in pypi_top1k:
    download_total = download_total + pkg.get('download_count')
    
missing_total = 0
for pkg in missing_pkg_list:
    missing_total = missing_total + pkg.get('download_count')
    
print('Total PyPi downloads 15561303313')
print('Total top 1K downloads: {}'.format(download_total))
print('Total missing pkg downloads: {}'.format(missing_total))
print('Percentage of top 1K downloads: {}'.format(download_total/15561303313*100))
print('Percentage of missing packages in top 1k downloads: {}'.format(missing_total/download_total*100))
print('Percentage of missing packages in total downloads: {}'.format(missing_total/15561303313*100))
# Out:
# Total PyPi downloads 15561303313
# Total top 1K downloads: 14403311239
# Total missing pkg downloads: 3323612917
# Percentage of top 1K downloads: 92.55851485760445
# Percentage of missing packages in top 1k downloads: 23.075339148407885
# Percentage of missing packages in total downloads: 21.35819121412173

# %% [markdown]
# ## Get conda-forge data

# %%
from bs4 import BeautifulSoup
import requests

url = 'http://conda-forge.org/feedstocks/'
cf_feedstocks = requests.get(url)
feedstocks = set()
soup = BeautifulSoup(cf_feedstocks.content, 'html.parser')
for item in soup.find_all('li', attrs={'class':'list-group-item'}):
    feedstocks.add(item.find('a').contents[0].lstrip().rstrip())

for fs in feedstocks:
    print(fs)
# Out:
# flask-potion
# r-bwstest
# sphinxcontrib-srclinks
# httpretty
# distro
# allennlp
# osmnx
# r-simcomp
# maya
# port-for
# pyjwt
# r-gsubfn
# setuptools-markdown
# agg-regrid
# nauty
# pseudonetcdf
# schema-salad
# coursera-dl
# r-msgps
# c99-to-c89
# pywin32
# r-rastervis
# pytest-ignore-flaky
# cwltool
# r-geor
# request
# sunpy
# r-htmltools
# pymemcache
# r-spacyr
# easy-thumbnails
# r-lightgbm
# r-lmertest
# r-pscl
# pygments
# reg
# r-npsurv
# pyct
# r-pinfsc50
# keystoneauth1
# openmp
# mycli
# r-rngtools
# r-prettygraphs
# r-doparallel
# nipy
# pyotp
# isl
# diff-match-patch
# pysot
# netcdf-scm
# r-intamap
# r-ptw
# nidaqmx-python
# wq.core
# pyjnius
# r-bmp
# shutilwhich-cwdpatch
# cudatoolkit-dev
# m2r
# r-sn
# shapelib
# halide
# xorg-xtrans
# libobjcryst
# r-biclust
# leptonica
# r-goodpractice
# backports_abc
# pep8-naming
# dis3
# freecad
# r-promises
# pylint
# r-rccmisc
# r-nloptr
# flake8-builtins
# lalsimulation
# r-subselect
# ldaptor
# enum34
# spyder-reports
# aioftp
# r-tfdatasets
# doc2dash
# bisonpp
# terraform-provider-logentries
# tempdir
# ipaddress
# sphinx-confluence
# r-sp
# r-waffle
# aioeasywebdav
# jupyterlab_launcher
# pdbpp
# auditwheel
# python-neo
# flask-rest-api
# r-colortools
# r-fftrees
# r-plumber
# r-robust
# root5
# r-rdpack
# gmprocess
# r-binhf
# r-data.table
# r-lambda.r
# mgwr
# r-markdown
# service_identity
# r-reticulate
# pyuca
# flask-principal
# cattrs
# pyside
# thrift_sasl
# cx_oracle
# cddlib
# proof
# adios-python
# r-fd
# rios
# atlantis
# r-libcoin
# r-filehash
# speaklater
# laz-perf
# wagtail-bakery
# elfutils
# pyblake2
# standard_names
# pytest-catchlog
# r-matrixcalc
# r-rook
# pytest-icdiff
# pywinpty
# r-ritis
# xorg-printproto
# ordereddict
# girder
# corral-pipeline
# pythesint
# preprocess
# r-webutils
# xz
# flann
# corner
# r-rfoc
# dirent
# r-distrex
# paprika
# fflas-ffpack
# dec2
# jupyter_nbextensions_configurator
# intake-astro
# notebook
# r-apatables
# r-hunspell
# r-lars
# r-evmix
# sagemath-db-graphs
# r-rversions
# r-dbplyr
# aipy
# perl-unix-processors
# conan
# neo4j-python-driver
# imapclient
# textdistance
# r-envstats
# numcosmo
# pocket
# version_information
# r-writexl
# phreeqpy
# kapteyn
# imageio
# click-log
# pyam
# lalmetaio
# tsl_ordered_map
# emoji
# py2cytoscape
# r-rvest
# psfex
# numpy_sugar
# jigsaw
# terraform-provider-http
# r-mcmcglmm
# r-cardata
# r-hdrcde
# r-dplyr
# polib
# spacy-model-pt
# almosthere
# azure-keyvault
# r-forge
# polyline
# graphql-js
# libnetcdf
# r-pcit
# r-mockery
# pyalveo
# chealpix
# django-daterange-filter
# sentry-sdk
# nappy
# transforms3d
# gstreamer
# r-osmar
# r-geem
# pywavelets
# typescript
# pony
# mypy_extensions
# r-nnls
# croaring
# pyxdg
# oclgrind
# r-cghflasso
# xorg-xf86rushproto
# r-bs4dash
# qutip
# r-segmented
# r-mpm
# csm
# pandas-datareader
# email_validator
# pykafka
# r-zeallot
# pyupgrade
# r-cobs
# terraform-provider-tls
# cmake
# cookies
# r-hrbrthemes
# racket
# clickhouse-cityhash
# metakernel
# pysal
# terraform-provider-librato
# r-prroc
# rsgislib
# yacs
# blosc
# r-gglasso
# django-mustache
# shogun-cpp
# github3.py
# r-highlight
# conda-smithy
# pyophidia
# qcelemental
# exec-wrappers
# pyuvdata
# webcolors
# xorg-makedepend
# pymor
# arb
# pytest-selenium
# r-assertive.properties
# r-adlift
# eventlet
# r-dotcall64
# joblib
# ghp-import
# selectors34
# imageio-ffmpeg
# r-minpack.lm
# r-progress
# r-orcme
# r-tidyverse
# netcdf-fortran
# spooles
# bob.learn.mlp
# kaldi
# transaction
# yodapy
# winpty
# inferno
# magic-wormhole
# lzstring
# libpciaccess
# wakatime
# easybuild-framework
# r-distillery
# r-hier.part
# r-subplex
# geotext
# output_viewer
# trimesh
# pyqode.qt
# r-pspline
# zeo
# r-rgdal
# libsemigroups
# sqlite
# terraform-provider-mailgun
# colour-science
# astroplan
# iterm2-tools
# flasgger
# r-ggfocus
# patsy
# ipympl
# regex
# r-drr
# static-frame
# h2
# mrcz
# r-rcppgsl
# flask-ldap3-login
# attrdict
# r-mixomics
# r-refund
# pythreejs
# oslo.i18n
# scrypt
# r-aws
# ebooklib
# svgwrite
# memoized-property
# r-rwave
# rowan
# tornado
# agate
# cloudpickle
# django-model-utils
# requests-futures
# r-rlas
# galario
# pyephem
# flask-restful
# r-rmallow
# qtlocation
# constantly
# flang
# terraform-provider-newrelic
# r-rcpptoml
# setproctitle
# ibis-framework
# webencodings
# python-multipart
# cis
# r-ks
# branca
# terraform-provider-ns1
# audi
# terraform-provider-mysql
# r-rcppparallel
# r-awsmethods
# pysmi
# edffile
# mputil
# dxfile
# dask-searchcv
# vega
# quantecon
# oauth2client
# r-logging
# sphinx-astropy
# r-shinystan
# conda-forge-repodata-patches
# hyperframe
# djangorestframework-gis
# r-svglite
# utide
# cbsyst
# pyembree
# r-skimr
# r-plot3d
# terraform-provider-profitbricks
# bob.ip.gabor
# alsa-lib
# palettable
# r-caroline
# gfortran_osx-64
# xorg-windowswmproto
# otsvm
# pandas_ml
# r-pwr
# r-nnet
# r-flock
# ncurses
# rdflib
# jupyternotify
# lalinspiral
# planarity
# hdmedians
# r-phylogeneticem
# openquake.engine
# r-segregation
# feather-format
# ddt
# splits
# asgiref
# infinity
# r-smotefamily
# pytest-datadir
# falcon
# cgsn_processing
# pyldavis
# elasticsearch-async
# loguru
# ftfy
# qgrid
# symengine
# libsass
# colicoords
# osmapi
# pytest-flakes
# utfcpp
# progressbar33
# phantomjs
# rpy2
# r-wdi
# fire
# fasttsne
# tokyocabinet
# pefile
# hoomd
# dask-image
# discretisedfield
# iris-grib
# xorg-xf86driproto
# simplekml
# astropy-healpix
# r-magick
# cypari2
# demoshell
# intake
# r-iswr
# r-xfun
# pycsw
# r-hmisc
# pytrackmate
# r-lexicon
# pendulum
# airflow
# r-colorspace
# pygeogrids
# pandas-highcharts
# r-aws.ec2metadata
# piqs
# salt
# r-strex
# mdx_gh_links
# gmpy2
# dockermake
# jupyter_cms
# lockfile
# flask-xml-rpc
# linecache2
# yarl
# r-sjstats
# sphinx-nbexamples
# pytweening
# r-webdriver
# r-lpsolve
# qgis
# unittest2
# numexpr
# r-spam
# r-scatterpie
# numcodecs
# r-nhmmfdr
# spacy-model-it
# r-limsolve
# r-directlabels
# pywin32-ctypes
# adjusttext
# flask-migrate
# r-purbayes
# ldc
# tifffile
# r-stringi
# pyzmq
# cson
# prefsync
# pytest-arraydiff
# curio
# pybtex-docutils
# partd
# win_unicode_console
# django-import-export
# xorg-xcmiscproto
# unidecode
# hide_code
# r-st
# r-kimisc
# conda-forge-ci-setup
# r-xtable
# backtrace
# simhash
# cryptography
# r-varselrf
# bob.io.base
# case
# great-expectations
# esmpy
# nilearn
# r-inlinedocs
# message-ix
# weightedstats
# r-cubature
# fonttools
# halide-python
# asyncpgsa
# concurrentloghandler
# r-diffr
# flask-restalchemy
# moola
# meshpy
# r-rzmq
# openpyxl
# werkzeug
# pyseidon
# pdfminer
# vaex-jupyter
# waf
# geoviews
# vobject
# google-cloud-core
# staticjinja
# tidynamics
# jasper
# ppl
# eqcorrscan
# jupyterhub
# scripting
# portalocker
# shedsidewinder
# r-googlevis
# aiosqlite
# sagenb
# xcb-proto
# pyelftools
# git_root
# coverage
# r-gprofiler
# jupyter_sphinx
# ghostscript
# lal
# pycvodes
# click
# hachoir-subfile
# jupyter_core
# pystan
# python-utils
# r-bma
# stopit
# fish
# r-multcompview
# vim
# pyvcf
# flask-rest-orm
# dbxfs
# qtkeychain
# grpcio
# memory_profiler
# ply
# pyhrf
# islpy
# pyjokes
# zdaemon
# terraform
# uritemplate
# openorb-data-bc430
# pytest-mpl
# spyder-line-profiler
# graphtools
# sfdmap
# echopype
# r-storr
# r-ggspectra
# r-akima
# pyee
# r-tidyxl
# r-esabcv
# torchfile
# python-primesieve
# hupper
# tensorflow
# sphinx-click
# backports
# libdb
# r-minicran
# colorspacious
# pdfminer.six
# r-rmtstat
# multiset
# jquery-ui
# livereload
# r-glmnet
# r-ggthemes
# pyferret
# r-quadprog
# r-selectr
# robotstatuschecker
# xorg-libxpm
# r-polynom
# r-tfmpvalue
# shortcutter
# agate-stats
# r-svmisc
# pyviz_comms
# bob.db.mnist
# r-mlr
# pytest-env
# jgo
# orange3-geo
# r-sys
# r-rbamtools
# suds-jurko
# scripttest
# pillow
# freeimage
# bzip2
# r-purrr
# livvkit
# r-modeest
# limix-legacy
# audiogrep
# r-irdisplay
# r-httr
# tpot
# cif2cell
# trmm_rsl
# r-gapminder
# xmlschema
# r-printr
# r-coranking
# quantities
# python-box
# marbles-core
# progress
# django-cachalot
# oath
# qupy
# oniguruma
# node2vec
# cmor
# nose-timer
# approxposterior
# r-hypergeo
# perl
# genson
# r-relimp
# waitress
# ds-lime
# asciinema
# r-loo
# pipdate
# djangorestframework-csv
# jupyter_dashboards
# pyinstaller
# pprofile
# pyparsing
# beautysh
# libogg
# salvus_mesher_lite
# pytimeparse
# r-pbivnorm
# dask-kubernetes
# dash-table
# r-cluster
# sadisplay
# sas_kernel
# r-uniqtag
# simanneal
# rust
# effect
# r-kza
# exifread
# bob.learn.linear
# sphinxcontrib-httpexample
# sdl2
# r-snowballc
# ccfits
# expat
# git-annex
# r-ggextra
# pybroom
# datalad
# thrift-cpp
# r-fansi
# eulxml
# r-margins
# mdsplus
# cfortran-cfitsio
# wordcloud
# ipyscales
# laszip
# dolfin-adjoint
# parsimonious
# r-rappdirs
# r-itertools
# quest
# widgetsnbextension
# cmocean
# r-metr
# jenkspy
# r-survminer
# r-coxboost
# user-agents
# cibots
# apache-beam
# bjoern
# r-getopt
# conda
# pygeometa
# ophyd
# tmtk
# r-png
# bumpversion
# conda-verify
# r-assertive.strings
# compiler-rt
# r-gtools
# r-ggpmisc
# legit
# dipy
# gama
# debtcollector
# pies2overrides
# strec
# behave
# svgutils
# elasticsearch
# gfan
# gap
# libadjoint
# libcmaes
# drmaa
# shellescape
# r-webshot
# r-wordcloud
# r-munsell
# jaraco.classes
# ocaml-num
# pre_commit
# cminpack
# aiozmq
# lalsuite
# sexpdata
# petsc4py
# mercurial
# libglu
# gitpython
# pytypes
# hyperspy
# geoip
# waybackpack
# indexed_gzip
# ipypivot
# h5py
# deprecation-factory
# pydecorate
# atk
# tachyon
# pyscrap
# r-tiff
# django-braces
# flask-autoindex
# r-oceanview
# neuron
# reportlab
# graphviz
# preact
# signac-dashboard
# pygraphviz
# guiqwt
# cf_units
# deps
# r-gparotation
# jquery-mobile
# r-grr
# python-coveralls
# strict-rfc3339
# openturns
# scikit-sparse
# r-tidylog
# intake-accumulo
# lesscpy
# r-rcpp
# uvicorn
# meson
# r-plotrix
# r-viridislite
# depi
# r-batchjobs
# shellingham
# botocore
# y_serial
# r-arrayhelpers
# dbt
# ezc3d
# plaster
# marbles
# dialite
# r-sparsemvn
# r-cowplot
# r-genalg
# r-irlba
# c3
# r-lmtest
# r-km.ci
# asciidoc
# modepy
# python-jose
# xorg-libxrender
# r-ipred
# path.py
# nox
# bdw-gc
# kafka-python
# mdanalysisdata
# nbrr
# vmprof
# deepgraph
# binaryornot
# jemalloc
# betamax
# pytest-flake8
# r-kernlab
# parsedatetime
# intel-ipp
# pytest-astropy
# xeus-cling
# point_cloud_utils
# gpstime
# clickhouse-driver
# youtube-dl
# serializable
# clblast
# toolchain
# elm
# speclite
# giac
# signac
# pyvo
# pybtex
# ocamlbuild
# pstdint
# preshed
# r-kpmt
# r-icluster
# r-repo
# gf2x
# panel
# tuiview
# zipp
# datrie
# symfit
# pysis
# terraform-provider-google
# pylint-plugin-utils
# r-xlsx
# addict
# terraform-provider-docker
# flask
# tsfresh
# r-ada
# r-pathological
# django-simple-history
# xmlrunner
# imagesize
# falcon-require-https
# flup
# r-sel
# rply
# conda-gitenv
# xdesign
# mpmath
# fast-histogram
# jupyterlab
# georaster
# eulexistdb
# pymks
# dxchange
# tvb-library
# markuppy
# geoviews-core
# portaudio
# morfessor
# flask-script
# healpy
# ghc-bootstrap
# otfftw
# pip-upgrader
# mdanalysis
# r-mapedit
# mlxtend
# r-profmem
# petulant-bear
# r-sf
# gst-python
# r-cometexacttest
# lcov
# dask-distance
# profilehooks
# srsly
# rasterio
# colormap
# ratelim
# implicit
# pytest-xdist
# r-plogr
# r-knitcitations
# r-raster
# r-manipulate
# cld2-cffi
# clint
# r-mvtnorm
# pyrtf
# yaml-cpp
# r-shinybs
# plotnine
# r-thinkr
# mpi
# r-rttf2pt1
# r-pkgbuild
# psutil
# confluence-publisher
# python-sounddevice
# r-shinycssloaders
# xorg-trapproto
# yeadon
# r-anomalydetection
# thinc
# astral
# django-wagtail-feeds
# tvb-framework
# trouve
# django-libsass
# r-conicfit
# gstlal
# tar
# django-leaflet
# pysolar
# r-rlabkey
# r-plm
# r-distances
# r-rlist
# r-matrixmodels
# r-qiimer
# bowtie-py
# xorg-bigreqsproto
# circus
# pyiron_atomistics
# r-memuse
# spectral-cube
# r-discretecdalgorithm
# r-gsw
# mantichora
# r-coxphf
# gitdb2
# libcroco
# r-ggridges
# folium
# elementpath
# r-tidyr
# pyimgur
# jsonpointer
# vlfeat
# theano
# nbformat
# glueviz
# pyqmix
# pulp
# commonmark
# pyflame
# r-rcdklibs
# msmtools
# smp
# r-rcpparmadillo
# fpylll
# trollsift
# fbprophet
# r-argumentcheck
# r-gridgraphics
# flit_install_py2
# r-sjlabelled
# r-support
# r-metap
# bob.io.audio
# terraform-provider-pagerduty
# wofpy
# r-randomfields
# codar2netcdf
# jaeger-client
# alphatwirl
# prov
# pyexcel
# r-inline
# nn
# jom
# r-bradleyterry2
# itypes
# djangorestframework-jwt
# ipdb
# r-rcppcnpy
# r-wrassp
# r-base
# pyasn1-modules
# r-checkmate
# cube_browser
# r-fitdistrplus
# r-futile.logger
# r-geepack
# qcengine
# wtforms-appengine
# r-kknn
# willow
# otagrum
# plaster_pastedeploy
# cxxtest
# spglib
# orcid
# yodatools
# spyre
# libffi
# terraform-provider-archive
# pywinauto
# cykdtree
# globus-sdk
# pyctest
# bob.io.video
# kyotocabinet
# ffpyplayer
# pylint-celery
# yggdrasil
# click-plugins
# omcompiler
# dask-yarn
# tenacity
# aiida-core
# pyodbc
# shed
# pandoc-attrs
# smt
# backports.functools_lru_cache
# libcomcat
# ipython
# priority
# r-hive
# swagger-django-generator
# xorg-libxft
# r-zcompositions
# jsonlines
# altair
# dynesty
# statuspage
# doublemetaphone
# r-oce
# contextlib2
# pygments_anyscript
# r-timsac
# pyfpgrowth
# xlntpyarrow
# tesseract
# tweepy
# scikit-allel
# pylama
# pytest-picked
# spm1d
# lua-luafilesystem
# google-api-core
# xmitgcm
# alabaster
# r-shinydashboard
# lz4-c
# terraform-provider-vsphere
# catch2
# privy
# ipython_memory_usage
# r-matching
# somoclu
# libdrm
# py-gfm
# jupyter_kernel_gateway
# r-mlgt
# pocketsphinx-python
# web.py
# pytest-clarity
# r-clipr
# r-probably
# libsigcpp
# pyfizi
# r-simpleboot
# salib
# r-ppls
# pyutilib
# pyquery
# chart.js
# nds2-client
# r-ggpubr
# awesome-slugify
# pygridtools
# python-fitparse
# pythran
# glmnet
# gengetopt
# rpaths
# dash
# datefudge
# gast
# graphicsmagick
# openh264
# easyprocess
# chemdataextractor
# biggus
# cchardet
# sqlobject
# pymssql
# fs.sshfs
# jupyterthemes
# toml
# r-pbdzmq
# r-svgui
# bayeswave
# r-threejs
# tox
# lalinference
# sleekxmpp
# feedfinder2
# r-jade
# sseclient
# r-influencer
# django_polymorphic
# r-survxai
# jeepney
# sasview
# terraform-provider-triton
# bob.ip.draw
# arrow
# s3contents
# python-dateutil
# r-gsl
# pyahocorasick
# bamnostic
# ipopt
# qt_binder
# pyevtk
# cachy
# r-elasticnet
# scikit-beam
# r-minqa
# r-cramer
# dask-ndfourier
# iris-sample-data
# os-service-types
# magics
# prawcore
# pylint-flask
# fig2dev
# geojsonio
# r-autoplotly
# r-lmoments
# terraform-provider-nomad
# flask-httpauth
# r-dosnow
# azure-mgmt-storage
# r-boruta
# h5io
# dj-static
# r-bglr
# pynacl
# r-effsize
# r-rvaidememoire
# pandas-compat
# dask-glm
# pygeoip
# xtensor-julia
# r-s4vd
# model_metadata
# r-dismo
# fenics
# r-ggupset
# r-settings
# r-leaflet.extras
# scikit-rf
# xorg-resourceproto
# nginx
# mpb
# gazar
# r-jpeg
# libsemigroups-python-bindings
# tabulator
# r-fabricatr
# r-rcmdrmisc
# root_numpy
# terraform-provider-dyn
# flake8-quotes
# routes
# pymt_hydrotrend
# pudb
# libhwloc
# link-traits
# pyramid
# r-learnbayes
# haversine
# vault
# python-kubernetes
# jsonnet
# python-markdown-math
# bob.ip.flandmark
# xpdan
# r-here
# libunistring
# videogrep
# r-mcmc
# r-corrgram
# pygslodeiv2
# r-truncdist
# r-suppdists
# terraform-provider-consul
# webassets
# openmpi
# r-rspectra
# r-rebus.unicode
# netcdf4
# molpx
# filesystem-spec
# r-units
# blis
# r-waterfalls
# zeromq
# papermill
# r-gridextra
# uproot
# draco
# qscintilla2
# vmtouch
# flask-marshmallow
# control
# papillon
# r-calibrate
# r-stapler
# spyder-notebook
# gensim
# publish
# sk-video
# splunk_handler
# repoze.lru
# r-r6
# r-rapidatetime
# datacache
# dsc
# pytz
# perl-app-cpanminus
# pwkit
# amplpy
# r-rapidjsonr
# r-scico
# u3d
# easytest
# py-cpuinfo
# aldjemy
# r-gamboostlss
# batman
# pgplot
# vaex-core
# r-squarem
# ragel
# pymedphys
# r-ic10trainingdata
# begins
# gunicorn
# pymt_child
# conda-env
# mesalib
# r-openmx
# progress_reporter
# r-delaporte
# gst-orc
# r-polylabelr
# cppunit
# azure-nspkg
# r-rvg
# md-toc
# neomodel
# python-bidi
# python-jenkins
# arpackpp
# compilers
# r-mgsub
# pysheds
# container-diff
# ezdxf
# pysolr
# timml
# vdt
# openssl
# txaio
# r-pmcmr
# librsvg
# django-fsm
# r-mrmre
# r-scatterplot3d
# r-baseline
# rebound
# hiveplot
# terraform-provider-statuscake
# python-snappy
# r-parcor
# r-qtlrel
# r-vioplot
# webdavclient2
# xxhash
# dbus-cxx
# r-rentrez
# asteval
# xorg-libxmu
# knack
# json-c
# jpype1
# statmorph
# r-rcppannoy
# pydotplus
# radical.pilot
# zodb
# flot
# r-ncdf4
# drf-haystack
# r-shinytest
# r-janitor
# pybufr-ecmwf
# r-mustat
# r-ff
# xo
# psyplot
# jupyter_conda
# cdms2
# pychef
# ioos_qartod
# r-kmsurv
# traja
# r-hexbin
# scipy
# r-giant
# r-readstata13
# wgetter
# r-htmltable
# r-sda
# r-ncbit
# fsleyes-widgets
# go-spatial
# graypy
# cfncluster
# lazy-object-proxy
# catzzz
# pycondor
# openpmd-api
# pytest-sugar
# r-dygraphs
# r-mitml
# r-crosstalk
# ufal.udpipe-temp
# cachetools
# lunardate
# marray
# nd2reader
# knitty
# flask-jsonpify
# xorg-scrnsaverproto
# anaconda-project
# hyper
# r-emdbook
# pickle5
# openssh
# r-geigen
# biotite
# py-ubjson
# r-mboost
# emcee
# sdl2_image
# pyserial
# stefuna
# sphinx-argparse
# pycryptodomex
# sphinxcontrib-autoprogram
# r-ggforce
# googlemaps
# r-proto
# r-pack
# cloud_sptheme
# r-rsvg
# asap3
# absl-py
# iris-ued
# allensdk
# visidata
# r-densityclust
# django-fixture-magic
# r-fdboost
# libcxx
# sed
# python-hostlist
# lua-luaposix
# pymongo
# r-genabel
# r-mc2d
# tierpsy
# google-cloud-monitoring
# httpagentparser
# libsecret
# pybuilder
# alex
# aiomysql
# beem
# libzip
# codacy-coverage
# crcmod
# r-moonbook
# python-spake2
# r-matrix.utils
# jupyter_highlight_selected_word
# snappy
# orekit
# r-paletteer
# otmorris
# pygam
# ocaml-findlib
# tabulate
# qwt
# r-flowr
# cxxopts
# gptools
# r-precrec
# kazoo
# quart
# overpy
# nr
# uproot-methods
# snap-cpp
# r-stanheaders
# pyexodus
# clhpp
# libxslt
# r-maptpx
# xorg-randrproto
# miktex
# r-zip
# r-randomizr
# filterpy
# r-cmls
# toastedmarshmallow
# azure-storage-common
# pidly
# boto3
# wmctrl
# envisage
# numpy_groupies
# xnat
# r-squash
# r-ggformula
# brewer2mpl
# olefile
# pytest-openfiles
# schwimmbad
# doxygen
# r-sentimentr
# r-bpca
# visvis
# asynctest
# r-juniperkernel
# r-swfscmisc
# jbig
# uncommitted
# orderedset
# r-haplo.stats
# pesummary
# r-snowfall
# r-ggseqlogo
# mock
# r-rsolnp
# pandoc-crossref
# pytorch-cpu
# zodbpickle
# prompt_toolkit
# astropy-sphinx-theme
# rapidpy
# gfortran_impl_osx-64
# r-svdialogs
# django-material
# libiconv
# r-gensa
# r-aggregation
# r-assertive.sets
# async-timeout
# r-pdftools
# tlslite
# panflute
# r-dofuture
# iso8601
# gdb
# itk
# fusepy
# python-editor
# r-ica
# spyder-terminal
# backports.test.support
# isodate
# r-shinyjs
# databroker-elasticsearch
# pygff
# r-isa2
# terraform-provider-opsgenie
# fasttext
# image-meta-tag
# r-shape
# ligo-lvalert
# mosfit
# sqlalchemy_exasol
# intake-xarray
# r-assertive
# r-maps
# nbdime
# r-poibin
# ffx
# zconfig
# pgcli
# django-bootstrap3
# vsc-base
# saspy
# zc.lockfile
# resonate
# xorg-inputproto
# lammps
# cvxpy
# cufflinks-py
# r-data.tree
# xorg-xextproto
# r-dcurver
# tblib
# hdf5
# r-ggalt
# terraform-provider-github
# radical.entk
# r-locfdr
# coconut
# r-binom
# traits
# tbb
# r-decoder
# shapely
# bob.db.base
# r-profvis
# jinja2-time
# metaio
# pyobjcryst
# r-gamlss
# flask-appbuilder
# mayavi
# hachoir-urwid
# r-cvtools
# mpfr
# r-rootsolve
# thriftpy
# jieba
# imexam
# fixie
# r-medicalrisk
# probableparsing
# hypercorn
# neunorm
# toolchain3
# sphinxcontrib-doxylink
# r-factormerger
# mahotas
# rsync
# assertpy
# r-rvmmin
# pingouin
# matplotlib
# oslo.serialization
# r-dmt
# prometheus_client
# xvfbwrapper
# py_gd
# sagemath-db-polytopes
# bootstrap_contrast
# aloe
# pyke
# pygeoif
# memprof
# cdp
# r-funr
# flask-bootstrap
# tableone
# r-farver
# r-rgexf
# rsa
# hdfs3
# pyftpdlib
# ruamel_yaml
# unixodbc
# r-janeaustenr
# bob.blitz
# r-microbenchmark
# python-lmdb
# r-snpls
# spacy-model-es
# odfpy
# r-xnomial
# pyfiglet
# bob.learn.activation
# ago
# r-estimatr
# r-fst
# perf
# xorg-kbproto
# r-prettydoc
# braggedgemodeling
# mpfi
# terraform-provider-influxdb
# r-logistf
# purepng
# django-storages
# elektronn2
# xorg-xproxymanagementprotocol
# r-qpdf
# pyelastix
# r-teachingdemos
# python-marisa-trie
# r-smoothmest
# python-xxhash
# r-barcoder
# ncpol2sdpa
# billingegroup
# r-magicaxis
# qsymm
# jmespath
# djangorestframework-yaml
# prettytable
# smokesignal
# terraform-provider-ovh
# requests-ftp
# pymt_cem
# r-piton
# xgboost
# pygments-cache
# r-udunits2
# django-nested-inline
# logilab-common
# mkdocs-bootswatch
# pynio
# pywr
# libxml2
# atpbar
# libxcb
# csvkit
# jupyterhub-yarnspawner
# r-gbm
# jq
# happybase
# newspaper3k
# mono
# lftp
# cssutils
# awkward
# scikit-fuzzy
# pyglet
# gridded
# casadi
# libmemcached
# reducer
# pylibmc
# flask-user
# pyngl
# pyro4
# xorg-libxau
# r-e1071
# r-exactci
# polyfempy
# r-clustergeneration
# r-loe
# more-itertools
# r-trust
# azure-storage-queue
# paramiko
# cloog
# refnx
# r-catboost
# lifelines
# r-ksamples
# go-bindata-assetfs
# ndcube
# r-xopen
# r-lintr
# django-ajax-selects
# sisl
# ccdproc
# flask-caching
# misaka
# quantlab
# fresnel
# r-brobdingnag
# r-sets
# bcolz
# r-pkgmaker
# restructuredtext_lint
# flake8-print
# enaml
# sasl
# r-filelock
# django-chunked-upload
# sphinx-autodoc-typehints
# r-uniqueatommat
# snakebite
# hiredis
# yamllint
# r-eml
# r-readbitmap
# docx2txt
# pyhmc
# aiocontextvars
# mrcfile
# hendrics
# metar
# r-openssl
# scikit-procrustes
# hopcroftkarp
# r-pvclust
# scikit-dsp-comm
# pixman
# ldas-tools-al
# r-epi
# r-flextable
# requests
# ipython-sql
# argparse
# cyclus-d3ploy
# r-rsnns
# librabbitmq
# r-alakazam
# r-argparse
# r-catools
# libsvm
# slicerator
# pgrouting
# xorg-xineramaproto
# azure-mgmt-resource
# flask-swagger-ui
# libradolan
# warctools
# r-egg
# r-plyr
# twython
# build_capi
# treq
# blinker
# r-devtools
# aws-requests-auth
# r-mefa
# r-repr
# pulsewaves
# r-biganalytics
# django-apptemplates
# clickhouse-odbc
# libcf
# setuptools-rust
# gsl-lite
# rpcq
# libsodium
# pycandela
# r-commonmark
# bravado
# scotch
# intervaltree
# mss
# r-assertive.data
# freexl
# python-stratify
# r-ggcorrplot
# python-avro
# cram
# flask-restplus
# parambokeh
# r-mhadaptive
# asyncqt
# pyomo.extras
# backports.weakref
# cftime
# bravado-core
# us
# django-versatileimagefield
# scalapack
# sshtunnel
# spyder-memory-profiler
# pocean-core
# mkdocs-bootstrap
# r-betareg
# r-protolite
# cifti
# r-futile.options
# paraview
# r-algdesign
# comet
# r-basix
# epc
# otfmi
# r-spatstat.data
# google-api-python-client
# r-kernelknn
# pthread-stubs
# r-rpart.plot
# event-model
# pyprind
# r-rcppprogress
# pdfrw
# c-ares
# camelot-py
# aiobotocore
# pycamhd
# py3dmol
# ptyprocess
# tectonic
# noise
# inline-html
# pyperclip
# jaraco.stream
# gtest
# ecmwf-api-client
# pyscenarios
# pyxdameraulevenshtein
# gpxpy
# seapy
# lesshat
# terraform-provider-random
# scikit-learn
# mathjax
# r-survey
# r-superpc
# mmh3
# fastrlock
# scrapy
# xray-vision
# mnist
# validictory
# refet
# r-ellipse
# r-blob
# python-hdfs
# vaex-hdf5
# jupyter-repo2docker
# vine
# r-mapview
# ldas-tools-cmake
# flask-webpack
# piranha
# gitdb
# menuinst
# r-multipanelfigure
# ggplot
# vs2008_runtime
# r-huge
# libspatialite
# r-dtwclust
# r-userfriendlyscience
# atomicwrites
# towncrier
# r-startupmsg
# cythongsl
# r-rrcov
# python.app
# pytest-ast-back-to-python
# jobtastic
# r-gwidgets
# veusz
# r-turner
# r-miniui
# r-rintrojs
# pyqode.python
# cppheaderparser
# df2gspread
# r-logicreg
# ua-parser
# cssselect2
# pcre
# lame
# validate_email
# hs_restclient
# pyproj
# socat
# r-argonr
# libunwind
# colored
# r-cooccur
# xorg-xproto
# pyworkout-toolkit
# backports.csv
# sage
# r-misctools
# flake8-polyfill
# m2w64-muparser
# r-quandl
# jsonref
# conda-exec
# sfepy
# mplleaflet
# r-statnet
# social-auth-app-django
# r-sourcetools
# clyent
# pyhum
# openjpeg
# py2swagger
# azure-mgmt-network
# pango
# r-diptest
# slacker
# bumps
# bob.math
# django-filter
# oletools
# avro
# terraform-provider-fastly
# forestci
# brotlipy
# graphql-server-core
# blaze
# glpk
# grip
# tikzmagic
# r-flux
# r-rnifti
# z5py
# r-ape
# r-formula.tools
# r-finch
# clcache
# tensorly
# npctypes
# texext
# pysnmp
# r-processx
# missingno
# tuna
# pyasn1
# sampledb
# dpath
# numpy-stl
# numba
# librosa
# ngmix
# r-lim
# r-rggobi
# whichcraft
# larray-editor
# diffoscope
# libgsasl
# r-agricolae
# xorg-libxcb
# databroker
# flatten_json
# webruntime
# bagit
# kuyruk
# chardet
# crystals
# randomcolor
# r-tcltk2
# r-arules
# xorg-fontcacheproto
# pymodbustcp
# orange3
# ezget
# nodebook
# r-kableextra
# r-lahman
# hdijupyterutils
# r-lda
# attrs
# icdiff
# r-sjmisc
# the_silver_searcher
# r-rcsdp
# pycovjson
# trilinos
# python-cpl
# doctr
# ninja_syntax
# r-fwdselect
# r-geosphere
# r-mcl
# robotframework-seleniumlibrary
# jupyter_dojo
# simplejson
# conjure-python-client
# kealib
# onnx
# r-aws.signature
# dicttoxml
# scipy-sugar
# stashy
# pymbolic
# l18n
# moab
# r-textrecipes
# mplcursors
# nose
# cppcheck
# pytest-faulthandler
# scattertext
# adios
# luajit
# skyfield
# r-ore
# django-extensions
# docker-py
# dolfyn
# stdlib-list
# cyan
# py-fann2
# scilab
# typechecks
# pygsp
# jupyter_full_width
# cwl_runner
# m4
# textblob
# r-sfsmisc
# cling
# libtiff
# cgroupspy
# py_entitymatching
# libgfortran
# flopy
# r-ash
# psy-simple
# pycapnp
# phonopy
# pytest-virtualenv
# fmilib
# r-rncl
# r-bookdown
# bluesky
# jupyterhub-ldapauthenticator
# azure-storage-file
# qwtpolar
# r-grimport
# r-cnogpro
# h11
# c-progressbar
# oommfodt
# armadillo
# quart-cors
# eofs
# xarray-extras
# pytoml
# cytoolz
# pyrobuf
# r-jcolors
# python-engineio
# openstacksdk
# pylibscrypt
# pyodeint
# r-cvst
# smpeg2
# numpy-indexed
# zict
# mastodon.py
# depfinder
# audioread
# r-oompadata
# keras
# r-mlapi
# r-nistunits
# gulp-util
# r-radix
# pkg-config
# geopy
# xtensor-blas
# setuptools_scm_git_archive
# r-heatmap3
# xpdview
# django_coverage_plugin
# junit-xml
# r-rsample
# r-fastica
# pymc
# gnutls
# nbbrowserpdf
# npth
# r-gamlss.data
# genesis-pyapi
# r-netrankr
# mypy
# r-genetics
# quantlab_launcher
# gitea
# r-hiddenmarkov
# datreant
# dogpile.cache
# dominate
# r-bioset
# cmapy
# pypolyagamma
# w3g
# doit
# git-bash
# ruby
# python-irodsclient
# googleapis-common-protos
# ukbparse
# r-timereg
# marshmallow-jsonapi
# pyjwkest
# dash-core-components
# geojson
# r-metarnaseq
# r-captioner
# r-downloader
# dask-jobqueue
# asap
# r-dendsort
# numpydoc
# flake8-mutable
# apsw
# snowflake-connector-python
# better_exceptions_fork
# nodeenv
# wagtail
# idna
# ldas-tools-ldasgen
# pari
# xproperty
# requests-oauthlib
# torsiondrive
# courtana
# r-dtt
# r-gplots
# glmnet_py
# r-reordercluster
# kombine
# notedown
# nose_xunitmp
# pyugrid
# versioneer
# azure-mgmt-authorization
# cairocffi
# ghost.py
# r-globaloptions
# leather
# pathtools
# r-inum
# nbgrader
# r-additivitytests
# ntl
# pyasdf
# pytim
# r-mcmcpack
# uritemplate.py
# hyperspy-gui-ipywidgets
# r-officer
# dustmaps
# ipyparallel
# cachecontrol
# lancet
# oslo.config
# r-shiny.semantic
# r-matrixeqtl
# ocaml
# sherlockml-boltzmannclean
# simhash-py
# r-phangorn
# orange3-imageanalytics
# r-diffusr
# twofish
# azure-common
# gflags
# anyjson
# r-assertive.datetimes
# spyder-kernels
# python-daemon
# cfunits
# xorg-libxaw
# xesmf
# cpplint
# libgpg-error
# sep
# pyvisa
# gshhg-gmt
# django-allauth
# r-speedglm
# r-bestglm
# r-tsp
# backports.shutil_get_terminal_size
# xlsxwriter
# cairo
# dash-html-components
# tifffolder
# unzip
# zookeeper-c
# imgurpython
# descartes
# scikit-ued
# nbconvert
# intake-parquet
# trollius
# spdlib
# r-invariantcausalprediction
# keyring
# r-relations
# pyreadr
# django-appconf
# r-infer
# pyexcel-xlsx
# terraform-provider-powerdns
# pynumpress
# django-viewflow
# pyresttest
# xorg-libxinerama
# modsecurity
# xorg-xf86dgaproto
# r-tmle
# clangdev
# r-scrt
# flask-mail
# httmock
# r-jmvcore
# r-caret
# gridgen
# r-sweidnumbr
# hug
# sphinx-autoapi
# r-lsei
# r-polyclip
# dask-core
# r-bench
# xorg-libxtst
# importscan
# r-goric
# r-poilog
# fabio
# sagelib
# r-spatest
# pipreqs
# sortednp
# handsontable
# records
# r-rcpproll
# boltons
# neurosynchro
# pyqode.core
# jstz
# kalasiris
# requests-toolbelt
# sphinxcontrib-openapi
# pbr
# r-rstanarm
# dcm2niix
# r-config
# pyinotify
# genpy
# python-hookman
# multipledispatch
# glog
# pyranha
# pigar
# r-howmany
# sortedcontainers
# ase
# pytest-xvfb
# r-spelling
# r-princurve
# r-desc
# rfc3986
# pythia8
# freediscovery
# r-pcapp
# django-jquery
# libframe
# tempita
# python-confluent-kafka
# r-text2vec
# apistar
# r-gmm
# r-compute.es
# r-fpp2
# r-yaimpute
# pylint-common
# r-boolnet
# r-ggiraph
# glymur
# orca_test
# dawg
# r-ellipsis
# sphinxjp.themes.solarized
# pypubsub
# seaborn
# streamz
# fixtures
# impyla
# r-r.methodss3
# cdecimal
# r-rtweet
# itkwidgets
# r-mixsqp
# caproto
# pscript
# conda-forge-build-setup
# r-feather
# r-roxygen2
# openorb-data-de430
# pathos
# r-nmf
# redux
# r-highr
# fretbursts
# libpysal
# ipywidgets
# cyflann
# dash-daq
# spacy-model-en_vectors_web
# pywaffle
# azure-mgmt-nspkg
# ecl
# pynfft
# impactutils
# wsproto
# saga-python
# r-gh
# openexr
# r-kedd
# tinycss
# khronos-opencl-icd-loader
# click-help-colors
# r-neuralnet
# pyside2
# catimg
# tabula-py
# dbus
# slackclient
# thermotools
# r-animation
# r-rhandsontable
# windrose
# wstools
# attrs-sqlalchemy
# traceback2
# tokei
# r-rgeos
# jaws
# convertdate
# cmd2
# obspyck
# r-exposition
# r-robustbase
# reprounzip
# r-mclust
# census
# svg2png
# gnureadline
# flask-redis-helper
# reports
# r-rlrsim
# spyder
# xdg
# zope.interface
# lsstdesc.coord
# pytest-console-scripts
# mako
# moto
# requests-cache
# requests_ntlm
# r-cmprsk
# cached-property
# html5lib
# distributed
# r-pca3d
# plotly
# holoplot
# python-patch
# mongoengine
# astrocats
# r-dials
# vega3
# r-qtlcharts
# python-pdfkit
# azure-mgmt-msi
# r-ggjoy
# appnope
# qjson
# r-radiant.data
# django-nose
# pycoast
# dask-imread
# r-shinyalert
# arpack
# wsgiref
# kenjutsu
# r-obistools
# aws-iam-authenticator
# django-bakery
# r-docopt
# pyaudio
# r-uuid
# gwosc
# xsv
# f2c
# pygithub
# py_stringsimjoin
# mshr
# psyplot-gui
# radical.analytics
# scs
# click-completion
# datreant.data
# phonenumbers
# intel-hybrid-driver
# r-lsa
# r-anytime
# r-relaimpo
# typing_extensions
# pytorch-pretrained-bert
# r-tidyposterior
# vue
# markov_draftjs
# xorg-xf86bigfontproto
# oset
# r-textclean
# r-goftest
# atomap
# cfitsio
# calliope
# pysdl2
# mmtf-python
# ujson
# jug
# configobj
# r-rsm
# larray_eurostat
# bunch
# jupyter-hdfscm
# r-svd
# libgd
# ijroi
# r-metrics
# r-paco
# r-worrms
# pygc
# x264
# jupyter_server
# pygypsy
# pymsgbox
# python-memcached
# r-clustermq
# r-intervals
# wasabi
# py6s
# weightedcalcs
# dependencies
# bob
# python-libarchive-c
# r-proj4
# python-twitter
# sedflux
# conda-devenv
# r-ttr
# vifm
# urllib3
# perl-xml-parser
# r-plspm
# ipaddr
# autodocsumm
# r-snftool
# jpeg
# premailer
# xorg-font-util
# databases
# r-idpmisc
# astcheck
# cmt
# r-r2d3
# r-geometry
# yarn
# aioslacker
# pyreadline
# r-cvxbiclustr
# ipywidget-pivot-table
# otwrapy
# pyorbital
# wrapt
# r-gsalib
# ps2ff
# nitime
# r-demerelate
# r-depmixs4
# libdrs
# virtualenv
# globus-cli
# sphinx-pypi-upload
# r-uroot
# django-js-asset
# funcargparse
# sasmodels
# singular
# r-sqldf
# sphinxcontrib-bibtex
# swagger-spec-validator
# r-forestplot
# igraph
# oommf
# sos-pbs
# r-kohonen
# terraform-provider-ignition
# sortedcollections
# ipydatawidgets
# r-pls
# r-randomforestsrc
# jupyter_qtconsole_colorschemes
# r-desctools
# vega_datasets
# consul
# cfgv
# conda-mirror
# flask-basicauth
# pywim
# libjpeg-turbo
# mpich
# azure-cosmos
# smartypants
# textwrap3
# r-rlab
# xarray
# r-coin
# r-scales
# simdna
# pygit2
# ligotimegps
# vectormath
# scitime
# dockerspawner
# r-missmda
# pyspeckit
# inkscape
# ukpopulation
# r-imbalance
# ilamb
# plumpy
# pycbc
# tmux
# langdetect
# libuuid
# nanoflann
# moment
# parcels
# sphinxcontrib-spelling
# intervals
# r-multicool
# r-reshape2
# imread
# pygeobase
# imagehash
# clickclick
# simupop
# flake8
# paver
# jsonapi-client
# gawk
# podaacpy
# poster
# parcel
# r-tokenizers
# et_xmlfile
# r-igraph
# vigra
# ephem
# python-gitlab
# django-uuidfield
# giza
# multinest
# xorg-libsm
# oyaml
# m4ri
# qtwirl
# hdmf
# r-prettyunits
# kdtree
# jira
# readme_renderer
# ibex
# r-mratios
# r-ics
# adal
# pypeg2
# pivy
# nipype
# chaospy
# triangle
# fastscapelib
# dulwich
# r-breakdown
# clusterpy
# sphinx-issues
# iteration_utilities
# libtool
# cython
# r-triebeard
# gdbm
# pydrive
# r-sparsebn
# gwtrigfind
# r-fastmatch
# fake-factory
# opentracing
# urwid
# reentry
# futures
# easybuild-easyblocks
# naima
# safe-netrc
# xonda
# r-chemometrics
# terraform-provider-bitbucket
# pymonetdb
# postgresql
# conda-testenv
# hypertemp
# r-estimability
# typing
# r-tidyselect
# resampy
# extras
# traces
# esgf-pyclient
# r-rlang
# docker-pycreds
# apipkg
# rw
# pycoalescence
# pylev
# r-mice
# kivy
# simplekv
# ampl-mp
# r-energy
# r-rerddap
# r-kernsmooth
# parquet-cpp
# coincbc
# megaradrp
# h5pickle
# pure-sasl
# r-plotroc
# r-lhs
# geoplot
# astroscrappy
# qt.py
# backoff
# fltk
# flake8-comprehensions
# applicationinsights
# igor
# mechanize
# oslo.utils
# r-lobstr
# connexion
# responses
# panedr
# msinttypes
# antlr
# greenlet
# girder-client
# r-optparse
# edit_distance
# colormath
# px4tools
# finitediff
# supervisor
# sphinx
# sstp-client
# r-gpseq
# pylint-django
# flask-rest-jsonapi
# frozendict
# statistics
# harfbuzz
# pathlib2
# r-pmcmrplus
# pynumero_libraries
# pydoe2
# r-mnormt
# r-pingr
# autoconf-archive
# jupyter_contrib_core
# cantools
# puremagic
# pyvtk
# r-mosaiccore
# xorg-fixesproto
# spylon-kernel
# djangorestframework
# anaconda-verify
# r-coxme
# pyncml
# flask-cors
# lyricsmaster
# six
# pysmbclient
# bob.db.iris
# instaseis
# treecorr
# pyrserve
# hachoir-metadata
# qtpy
# pygelf
# r-lassopv
# sphinxcontrib-dotnetdomain
# hpccm
# r-shinydashboardplus
# less.js
# configurable-http-proxy
# gulp
# python-crfsuite
# toolz
# django-crispy-forms
# ldas-tools-filters
# brent_search
# libxmlpp
# petsc
# terraform-provider-vcd
# cysignals
# pagmo
# jupyter_console
# freetype-py
# r-modelr
# markovify
# conda-wrappers
# r-gmodels
# r-circlize
# r-d3r
# ctds
# python-cufflinks
# py4j
# r-splitstackshape
# r-ascii
# dqsegdb
# xorg-xf86miscproto
# flask-apscheduler
# mercantile
# travis-encrypt
# r-ggdendro
# r-fda
# r-changepoint
# python-jsonrpc-server
# r-parsnip
# embree
# r-fingerprint
# binarytree
# r-knitrbootstrap
# r-rstudioapi
# fastimport
# terraform-provider-packet
# basemap
# r-tfruns
# markdown-checklist
# givaro
# pycwt
# strictyaml
# pastescript
# r-drc
# crontab
# clblas
# r-mitools
# django-celery
# pgspecial
# r-multitaper
# testtools
# azure-mgmt
# pyaxiom
# tasklogger
# alpenglow
# pyhamcrest
# lxml
# robotframework-sshlibrary
# libneuroml
# giflib
# cdsapi
# doc8
# openorb-eph-builder
# cfanalytics
# davix
# agate-lookup
# glfw
# django-enumfields
# r-fftwtools
# ldas-tools-framecpp
# fisx
# featuretools
# foundation-sites
# otmixmod
# flang-meta
# py-bash-completion
# r-randomfieldsutils
# r-nardl
# libctl
# autobahn
# r-rvcheck
# mne
# textacy
# pyppdf
# r-highcharter
# shutilwhich
# ppft
# terraform-provider-gitlab
# django-pyodbc-azure
# phosphor
# r-tensorflow
# r-fail
# r-domc
# r-fontquiver
# dramatiq
# pshell
# pymc3
# r-fpc
# chemfiles-python
# r-xtractomatic
# r-rinside
# galsim
# qcfractal
# wfdb
# wradlib
# r-generics
# xwidgets
# multi_key_dict
# r-latex2exp
# python-slugify
# grove
# r-tmb
# alphalens
# r-lle
# ocl_icd_wrapper_apple
# exempi
# r-contrast
# obvious-ci
# build-capi
# poap
# r-mertools
# mo_pack
# cov-core
# r-mcbiopi
# lime
# ldas-tools-diskcacheapi
# coinmp
# falcon-auth
# r-qvcalc
# genshi
# vispy
# bob.learn.libsvm
# backcall
# paegan
# r-circular
# r-hh
# dropbox
# terraform-provider-heroku
# ispyb
# pymapd
# r-europepmc
# r-gclus
# incremental
# asdf
# django-filer
# p_astro
# vincent
# r-narray
# contact_map
# terraform-provider-panos
# dpkt
# anaconda-client
# pyobjc-framework-cocoa
# sagemath-db-elliptic-curves
# pysparse
# sphinxcontrib-autodoc_doxygen
# pytest-smartcov
# asammdf
# rope
# r-xmlschema
# tldextract
# r-mi
# vmd
# cairomm
# eliot
# pluginbase
# pytest-metadata
# geopandas
# r-xmisc
# raven-aiohttp
# inflect
# wget
# happy
# m4rie
# frosted
# r-rationalexp
# xorg-libx11
# tensorflow-hub
# plac
# ptemcee
# r-crf
# r-rcgmin
# rhash
# r-tidypredict
# lpsolve55
# wcsaxes
# monkeytype
# dask-funk
# httpie
# nb_anacondacloud
# blessings
# r-vctrs
# symmetrica
# kubernetes-helm
# r-arm
# prospector
# scikit-data
# editdistance
# r-semtools
# r-gdalutils
# r-crayon
# libwebp
# r-fts
# r-biasedurn
# flask-seasurf
# flask-oauthlib
# packmol
# spython
# python-flint
# retrying
# sensorml2iso
# r-gwidgetsrgtk2
# r-bold
# r-ggdistribute
# kafkacat
# pyunlocbox
# hachoir-wx
# capturer
# betse
# sanic
# r-rio
# xlrd
# autovizwidget
# advbumpversion
# gmp
# serpent
# r-sroc
# matplotlib-venn
# r-rfpermute
# parse_type
# graphql-relay
# path-and-address
# bob.db.atnt
# terraform-provider-template
# uwsgi
# scikit-image
# desktop3
# mccabe
# spdlog
# emperor
# r-purrrlyr
# r-sendmailr
# snowballstemmer
# py2neo
# pypugjs
# pyfftw
# cfflib
# ptable
# fswatch
# atomsk
# child
# fftw
# pymt
# azure-storage-nspkg
# py_dempster_shafer
# smmap
# rednose
# terraform-provider-rundeck
# compas_fab
# deap
# helper
# python-termstyle
# sentinels
# r-tensora
# pytzdata
# python-language-server
# namedlist
# r-prophet
# coloredlogs
# pytest-sftpserver
# bgen
# tinyrpc
# r-spatstat
# mockredispy
# pyoos
# hachoir-core
# libaec
# hypre
# r-sparsem
# django-debug-toolbar
# r-emdist
# libntlm
# splauncher
# hyperspyui
# django-nested-admin
# azure-cli-core
# r-base64enc
# falcon-docs
# xeus
# comtypes
# filesdb
# sciluigi
# lmod
# xerces-c
# bidict
# libflac
# r-pracma
# pymagej
# lazygit
# su-exec
# sundials
# flask-restless
# humanize
# pytmatrix
# platypus-opt
# ndcsv
# r-brms
# mdsrv
# r-rgl
# qd
# r-wikitaxa
# libatomic_ops
# usaddress
# flake8-docstrings
# django-configurations
# straditize
# r-survmisc
# holopy
# marshmallow-sqlalchemy
# r-ergm.count
# terraform-provider-grafana
# r-pairsd3
# setuptools_subversion
# flask-uploads
# pymodsecurity
# r-patpro
# r-sodium
# performance
# mimerender
# libblitz
# django-jsoneditor
# gsl
# axelrod
# r-gribr
# statsmodels
# xapian-core
# deicode
# lief
# zappy
# execnet
# terraform-provider-dnsimple
# usgs
# mapclassify
# r-infuser
# diffpy.utils
# pyfmmlib
# r-clisymbols
# coveralls
# dioptas
# lightfm
# clsparse
# cni
# dask-ndmorph
# beaker
# r-threeway
# xleaflet
# skijumpdesign
# ssh2-python
# pytest-socket
# egal
# libkml
# xsimd
# jupyter
# pytest-variables
# algopy
# django
# r-dunn.test
# reindent
# hmat-oss
# terraform-provider-local
# wtf-peewee
# fmpy
# formencode
# oic
# xorg-glproto
# python-chromedriver-binary
# py-pandoc-crossref
# rtree
# psy-reg
# r-clues
# nameparser
# r-qdaptools
# pyfmi
# vcversioner
# pygpu
# visdom
# terraform-provider-digitalocean
# r-flare
# watchdog
# cgal
# dynamicisttoolkit
# r-ssoap
# lark-parser
# yt
# yaml
# parsley
# vaex-viz
# r-bayesm
# mplview
# r-tinytex
# r-bootstrap
# epic2cf
# xrootd
# orange3-educational
# namaster
# vic
# r-rsqlite
# django-mptt-admin
# voila
# r-shinyhelper
# python_http_client
# r-wavethresh
# funcy
# cssselect
# loghub
# libxc
# r-microseq
# otrobopt
# r-mime
# pyface
# rdkit
# einsteinpy
# r-statmod
# itsdangerous
# shortuuid
# curl
# mpifft4py
# pickleshare
# selenium
# sparqlwrapper
# dataclasses
# bkcharts
# nb2plots
# radio-beam
# pyimagej
# permamodel
# r-rcppeigen
# r-readmzxmldata
# r-packrat
# pywps
# mkl_fft
# pysoundfile
# aenum
# python-docx
# landsat_util
# r-ffbase
# ipyslurm
# conda-execute
# pyiron_base
# mpc
# limix-inference
# hyperspy-gui-traitsui
# r-beanplot
# bats-core
# r-hoardr
# ndarray_listener
# xpdsim
# jsondiff
# libmagic
# r-nls2
# r-superlearner
# pyhocon
# lighttpd
# emacs
# jags
# requests_download
# keepalive
# r-iso
# scikit-bio
# chartkick
# brain-isotopic-distribution
# pandas-plink
# zeep
# r-lsr
# r-getpass
# lld
# jquery
# atom
# gwcs
# django-taggit
# ecm
# nspr
# nbrsessionproxy
# newrelic
# lagranto
# libarchive
# r-sparselda
# r-stopwords
# r-googleauthr
# r-sparklyr
# r-pals
# ctk-cli
# orange3-singlecell
# array2gif
# bmi-tester
# nxviz
# pyphen
# r-deoptimr
# interlap
# r-soniclength
# rpdb
# easybuild-easyconfigs
# luarocks
# r-reportr
# postgres-xl
# libtar
# jsonschema
# pep257
# kubernetes-federation
# runipy
# pysw4
# astro-gala
# mdsynthesis
# xorg-renderproto
# bcdoc
# dask-ndmeasure
# scour
# google-cloud-sdk
# openspecfun
# pyquil
# r-aod
# capnproto
# fastnumbers
# filechunkio
# time
# python-fmask
# jdcal
# requirements-detector
# pywinhook
# dask-ml
# libutf8proc
# cairosvg
# satsearch
# libdap4
# django-test-plus
# fsleyes
# r-xlsxjars
# ansimarkup
# openmeeg
# pyuv
# sphinx-releases
# r-digest
# sdl2_ttf
# torchvision
# gdcm
# python-pkcs11
# bob.core
# ipywe
# r-outliers
# bleach
# mockupdb
# r-prettymapr
# r-yarrr
# rapidsim
# flask-couchdb
# r-optextras
# lorem
# adaptive
# geometric
# fusepyng
# keras-preprocessing
# r-drat
# r-performanceanalytics
# r-plsvarsel
# setoptconf
# libspatialindex
# shove
# compliance-checker
# r-showimage
# gudhi
# hunspell-en
# pyamg
# xorg-evieext
# easydev
# bob.ip.optflow.hornschunck
# sphinxcontrib-websupport
# r-countrycode
# tensorboardx
# jinja2
# libosxunwind
# pyiron_vasp
# r-startr
# cvloop
# proj.4
# pyexcel-ezodf
# r-yaml
# yapf
# colorama
# pigz
# oommfc
# r-maptools
# r-rjsonio
# oceans
# scikit-video
# libsndfile
# muparser
# larray
# datreant.core
# modflow2netcdf
# r-latticeextra
# zbar
# openmesh
# r-bigstep
# r-linselect
# trackpy
# watchtower
# sphinxjp.themes.impressjs
# lightkurve
# terraform-provider-logicmonitor
# r-rtensor
# libevent
# peakutils
# g2clib
# divebomb
# mplexporter
# fplll
# sompy
# bc
# sh
# r-survauc
# webob
# r-reprex
# vc
# starry
# r-parmigene
# multicore-tsne
# r-rly
# munkres
# yajl
# polcart
# r-umap
# r-slam
# msmbuilder
# ecmwf_grib
# hive-thrift-py
# r-reshape
# findutils
# annexremote
# pykalman
# warc
# simbody
# diffpy.structure
# aiida-crystal17
# r-rarpack
# r-gwidgetstcltk
# skater
# r-etm
# json-rpc
# mpld3
# arcsi
# r-ineq
# entwine
# r-hiver
# r-ensurer
# binaryen
# czmq
# tidy_headers
# nestly
# altdphi
# xorg-libxfixes
# seawater
# r-qrcode
# libmatio
# agate-remote
# gherkin-official
# r-dtw
# pytables
# more.pathtool
# r-haven
# r-signal
# make
# libgdal
# python-annoy
# pycountry
# secretstorage
# line_profiler
# r-rapportools
# matchpy
# rever
# pyvisa-py
# r-plsdof
# r-gglogo
# goftests
# pylogit
# pyroma
# pyiron_lammps
# ptvsd
# msg-extractor
# gdal
# intake-esm
# django-treebeard
# iolabs
# tokenize-rt
# r-snpassoc
# nettle
# configargparse
# sphinxcontrib-restbuilder
# bowler
# qds-sdk
# geos
# pangaea
# r-visdat
# venusian
# r-infotheo
# dbf
# r-vcdextra
# metawrap
# openblas
# fault-localization
# log4cpp
# fixie-creds
# spectral
# optpp
# r-photobiologywavebands
# valgrind
# python-rapidjson
# r-rebus.numbers
# json_tricks
# r-exact2x2
# autograd
# hdf5storage
# r-stringdist
# azure-servicemanagement-legacy
# streamz_ext
# retriever
# xsgen
# python-symengine
# glm
# r-httpuv
# r-proc
# helics
# r-sjplot
# django_compressor
# fitsio
# cell_tree2d
# networkx
# django-super-inlines
# r-tractor.base
# r-adehabitatlt
# eclib
# r-bdsmatrix
# mms-python-client
# radiospectra
# pydruid
# mosh
# r-combinat
# silx
# django-haystack
# numina
# cement
# r-mixtools
# lcalc
# r-ifultools
# libconda
# awscli-cwlogs
# bob.ip.optflow.liu
# r-rseis
# pyutilsnrw
# r-brglm
# r-desolve
# wurlitzer
# r-jomo
# apr
# orange3-network
# bitstruct
# r-visnetwork
# ipysheet
# ccache
# mpl_sample_data
# r-shinyace
# cyminmax
# pydsd
# parse
# lldb
# pynamical
# importlib
# r-maxstat
# viridis
# nco
# r-nparcomp
# keyrings.alt
# jwcrypto
# pyabel
# terraform-provider-scaleway
# scp
# sysv_ipc
# r-testthat
# pymatbridge
# r-shinyfiles
# r-assertive.matrices
# pycraf
# trash-cli
# r-ps
# eccodes
# octave_kernel
# libuv
# bw2speedups
# dask
# dask-drmaa
# brian2
# osmnet
# terraform-provider-kubernetes
# metpy
# gwyfile
# markupsafe
# tk
# petl
# abydos
# pynvim
# hdf4
# libgpuarray
# r-lasso2
# dqsegdb2
# importnb
# brotli
# r-spdep
# appdirs
# r-lime
# async
# r-ggeffects
# snuggs
# aws-sdk-cpp
# r-tidytree
# dask-sphinx-theme
# r-modeltools
# r-ucminf
# r-assertive.types
# r-pdist
# pathlib
# pygdp
# r-tclust
# django-environ
# pydicom
# scikit-umfpack
# snakefood
# spacy-model-de
# mu_repo
# ruamel
# ocl-icd
# dxfgrabber
# r-lidr
# r-rmixmod
# ffmpeg
# filebutler
# terraform-provider-circonus
# pyautogui
# r-conflicted
# r-adgoftest
# ovito
# asv
# appmode
# netifaces
# rise
# pyosf
# pyobjc-core
# libgap
# gj2ascii
# r-mongolite
# r-crul
# r-assertive.data.us
# r-genlasso
# r-mvoutlier
# r-shinythemes
# r-corrplot
# argh
# r-qdapregex
# r-spatialvx
# vitables
# pv
# apptools
# jaydebeapi
# r-gdata
# vs2015_runtime
# r-pan
# spiceypy
# leidenalg
# libksba
# terraform-provider-opc
# r-lme4
# lazy
# flake8-self
# ciocheck
# r-corpcor
# check
# r-r.oo
# r-cartography
# r-parsedate
# r-irkernel
# gmsh
# qtwebkit
# boost-cpp
# r-networkdynamic
# pandas-profiling
# colorclass
# r-phonr
# r-gfa
# wera2netcdf
# inifile
# toposort
# bgen-reader
# r-tidytidbits
# vulture
# r-ufs
# soupsieve
# pytest-forked
# requests-unixsocket
# jack
# r-padr
# tensorboard
# coin3d
# fastavro
# azure-mgmt-compute
# openldap
# double-conversion
# r-jsonlite
# patchelf
# cabal
# faker
# statsd
# r-mirt
# r-rredlist
# dbfread
# r-mhsmm
# r-formattable
# r-rcurl
# xorg-libxdmcp
# mapio
# pyrxp
# r-ncdunnett
# tsl_robin_map
# r-rmpfr
# bibtexparser
# kwant
# ag-grid
# lalburst
# libsigsegv
# outcome
# apispec
# freezegun
# r-r.utils
# r-gamlss.dist
# libconfig
# r-bitops
# agate-sql
# r-matrixstats
# sendgrid
# datadotworld-py
# r-keras
# draftjs_exporter
# bob.io.matlab
# cffi
# sphinxcontrib-httpdomain
# r-chemospecutils
# r-hsaur
# pymvpa2
# djangorestframework_simplejwt
# pyhdf
# r-praise
# sklearn-contrib-lightning
# flintqs
# isort
# pastedeploy
# elfx86exts
# r-solrium
# doct
# python3-openid
# gcsfs
# serpy
# pyobjc-framework-quartz
# r-default
# r-tm
# reprounzip-docker
# odo
# pkgconfig
# bump2version
# ipyleaflet
# pyprism
# sqlalchemy-utils
# axopy
# r-deriv
# rake_nltk
# ligo-followup-advocate
# perl-text-soundex
# textadapter
# openfst
# resonance
# megaman
# r-dendroextras
# dnspython
# fmipp
# python-xapian
# xerces-c28
# opt_einsum
# tinytimer
# pyosreplace
# r-ebayesthresh
# aospy
# openmc
# yaml2ncml
# flufl.enum
# r-copula
# permission
# r-rserve
# pytest-pep8
# onnx-tf
# regolith
# erddapy
# asn1crypto
# r-assertive.code
# anyqt
# flower
# coredns
# hachoir-regex
# r-formatr
# pyslet
# python-xlib
# quaternion
# decorator
# keras-applications
# qtpy-uic
# pep8
# radical.utils
# r-etrunct
# r-stm
# r-kappalab
# freetype
# agate-dbf
# flask-wtf
# pynco
# pdal
# pies
# miller
# pyseaweed
# skyarea
# zlib
# terraform-provider-datadog
# r-softimpute
# nansat
# stack
# r-liftr
# dcw-gmt
# django-rest-hooks
# altgraph
# xorg-libxt
# r-genenet
# sparse
# pyarrow
# shogun
# antlr-python-runtime
# xtensor-fftw
# cryptominisat
# future_fstrings
# donfig
# r-rngwell
# iapws
# r-tsne
# rq
# starlette
# orange3-text
# django-typed-models
# dsfmt
# datapackage
# nbtutor
# importlib_resources
# responder
# bowerstatic
# r-sparseinv
# baseband
# python-casacore
# orange3-bioinformatics
# jobs_done10
# r-bibtex
# r-spotifyr
# r-rmarkdown
# r-ddpcr
# simpletal
# umap-learn
# r-car
# google-cloud-bigquery
# pytest-localserver
# bilby
# mdtraj
# ldas-tools-ldasgen-swig
# args
# trio_asyncio
# intel-vaapi-driver
# go1.4-bootstrap
# factory_boy
# param
# r-ggedit
# requestsexceptions
# send2trash
# semver
# python-snap
# r-logspline
# nginx-module-njs
# r-bayesfactor
# opentsne
# r-glm2
# toro
# imagepy
# r-dfoptim
# reaktoro
# python-ironicclient
# translationstring
# rauth
# gwcelery
# libprotobuf
# r-incadata
# flask-apispec
# r-skat
# trollimage
# r-rmariadb
# r-enc
# r-elliptic
# sphinx-automodapi
# ioos_tools
# pygridgen
# r-rcircos
# r-sandwich
# terraform-provider-cloudflare
# pyrsistent
# qca
# spherical-geometry
# reproject
# r-opencpu
# pyrepl
# r-whoami
# azure-cli-telemetry
# r-naniar
# srm
# rfc3987
# r-tseries
# nuitka
# hydrotrend
# r-iotools
# tinyarray
# conda-build-all
# slda
# colorlog
# slepc4py
# shenfun
# r-dicekriging
# fludashboard
# luigi
# r-setrng
# r-assertive.reflection
# r-lemon
# flask-bcrypt
# flask-allows
# gmaps
# psycogreen
# oauthlib
# xraylib
# r-dendextend
# pykml
# r-circstats
# fs-gcsfs
# whitebox
# r-turboem
# r-wrs2
# scijava-jupyter-kernel
# terraform-provider-dns
# chemex
# cheroot
# celiagg
# ckanapi
# firelight
# r-english
# libpq
# pyresample
# libcflib
# elasticsearch-dsl
# centrally-managed-conda
# r-r.matlab
# python-cdo
# backports.tempfile
# earthsim
# ldas-tools-al-swig
# celery
# jupyter_latex_envs
# r-rainbow
# skan
# viscm
# r-rmr2
# aiosmtplib
# setuptools_scm
# sphinxcontrib-fulltoc
# intelhex
# xarray-simlab
# terraform-provider-icinga2
# r-spdata
# google-auth-httplib2
# r-diagrammer
# r-seacarb
# pox
# heliopy
# twine
# jsanimation
# python-can
# r-dbplot
# flexx
# r-sparsebnutils
# source-highlight
# terrainbento
# shap
# scarplet
# r-scrm
# pysvg-py3
# signac-flow
# r-catnet
# pymultinest
# r-stabs
# bz2file
# r-genabel.data
# tranquilizer
# pyspectral
# spyder-unittest
# dust_extinction
# betamax-matchers
# r-nleqslv
# r-globals
# liknorm-py
# pyspharm
# wcwidth
# pocketsphinx
# ruamel.yaml
# cliff
# vaex-astro
# r-missforest
# django-foundation-formtags
# anypytools
# blackbook
# google-apputils
# py3c
# quandl
# azure-servicebus
# gsd
# opcua
# cmarkgfm
# shade
# zip
# kiwisolver
# scikit-cycling
# future
# pysocks
# cassandra-driver
# opencv
# readline
# mysqlclient
# ftputil
# r-tensor
# idna_ssl
# pytest-watch
# r-multiway
# pyxb
# r-rclipboard
# humanleague
# pyomo
# r-fnn
# pycalphad
# r-ccapp
# monty
# george
# craftr
# nbserverproxy
# aubio
# circleci-helpers
# julia
# empath
# contextily
# libtheora
# r-utf8
# r-rsvgtipsdevice
# vacumm-data
# r-lava
# r-xmlparsedata
# pymunk
# mpir
# nlopt
# r-gmd
# pprintpp
# rapidjson
# django-reversion-compare
# flask-swagger
# r-aer
# r-ggrepel
# jsonapi-requests
# r-hypergea
# suitesparse
# creoleparser
# r-r2html
# flask-bower
# pytest-pylint
# bhmm
# r-bgmm
# umalqurra
# griddataformats
# pycifrw
# rabbitmq-server
# s3fs
# google-cloud-bigquery-storage
# pycairo
# slumber
# read-roi
# cdutil
# r-magic
# r-smvar
# py-pandoc
# xorg-damageproto
# rjsmin
# r-cvauc
# yail
# bfg
# lunr
# git
# glimix-core
# cquadpack
# jdatetime
# ocgis
# ordered-set
# pmw
# r-d3heatmap
# sdl2_mixer
# m2crypto
# slycot
# makedepf90
# r-rematch
# pycrs
# pyttk
# r-polspline
# gridfill
# apache-libcloud
# uvloop
# flask-sqlalchemy
# paste
# libgit2
# mpg123
# r-plotly
# xpdtools
# r-mlbench
# stingray
# r-protviz
# r-readbrukerflexdata
# catboost
# pydata-google-auth
# bourbon
# lalframe
# monetdblite
# lumicks.pylake
# glib
# pysqa
# sphinx_rtd_theme
# r-recordlinkage
# pydub
# r-dynamictreecut
# geohash2
# steem
# mox
# voeventlib
# xorg-xbitmaps
# glue-geospatial
# r-rann
# wtforms
# r-glue
# xorg-libxaw3d
# loky
# r-venn
# pytest-qt
# r-shinywidgets
# rejected
# ligo-gracedb
# ncl
# r-spatialextremes
# pycodestyle
# r-caper
# r-bindr
# chest
# r-htree
# vaex
# pytest-benchmark
# r-biomark
# r-sem
# userspacefs
# xorg-dmxproto
# azure-storage-blob
# pyemir
# openorb
# pyflakes
# r-coop
# unittest2pytest
# lzfse
# r-gsa
# configparser
# pysftp
# r-ggstance
# tomlkit
# go
# r-sigmajs
# beautifulsoup4
# dockerpty
# mando
# oq-engine
# georasters
# r-rmeta
# r-afex
# lintel
# r-timedate
# r-sizer
# r-mda
# parallel
# benchmark
# coffeescript
# setuptools-git
# terminaltables
# brent-search
# shellcheck
# r-r.rsp
# llvmdev
# wincertstore
# python-planarity
# python-monkey-business
# r-paramhelpers
# r-wikidatar
# hydroerr
# cyavro
# r-furrr
# pocl
# astor
# r-gam
# watermark
# tslearn
# netgen
# fslpy
# r-treatmentselection
# wrf-python
# libpng
# r-shinysky
# gsw
# r-coda
# astroml
# libidn11
# requests_pkcs12
# pyweed
# r-rpostgres
# rfpimp
# r-laplacesdemon
# pysurfer
# r-rebus
# redis-py
# matplotlibhelper
# vtk
# r-ini
# r-gistr
# r-treeman
# credstash
# openbabel
# jaraco.functools
# sklearn-contrib-py-earth
# ipython_unittest
# r-vdiffr
# r-idr
# yamlordereddictloader
# terraform-provider-chef
# xplot
# r-mvnormtest
# neovim
# r-ashr
# r-maldiquant
# r-memoise
# planetaryimage
# r-compquadform
# dask-tensorflow
# libssh2
# xpdacq
# bottle
# inflection
# promise
# svg42pdf
# tetgen
# imagingreso
# glances
# liquidprompt
# r-rematch2
# r-mba
# skorch
# r-shinyjqui
# r-mppa
# aiofiles
# gpflow
# r-assertive.files
# yt_astro_analysis
# pyopenssl
# r-forecast
# tinydb
# jupyterlab_server
# r-sme
# flask_table
# tzcode
# simpletraj
# docker-compose
# jupyter_contrib_nbextensions
# fatiando
# libsharp
# r-formula
# joommfutil
# r-doby
# rvlib
# flask-login
# osx-pocl-opencl
# pystache
# theanolm
# mysql-connector-python
# simple-salesforce
# pollster
# r-rgtk2
# motor
# appscript
# suspect
# r-smoothie
# lapack
# r-som
# r-emmeans
# r-ggfittext
# r-svunit
# r-labelled
# morepath
# r-fontliberation
# r-sparsepp
# dmd
# r-elpigraph.r
# r-naturalsort
# r-treemap
# e-antic
# r-expsmooth
# vertica-python
# r-rcppclassic
# xnumpy
# ccache-toolchain
# r-feature
# spreg
# r-chron
# multineat
# hickle
# croniter
# r-broom.mixed
# ciso8601
# halotools
# mdbenchmark
# opty
# phconvert
# r-ggsignif
# r-collateral
# bazel
# gridgeo
# r-dosefinding
# django-emailhub
# r-divemove
# libpcap
# wabt
# choicemodels
# shyaml
# r-lazyeval
# flatbuffers
# featherhelper
# icalendar
# procrunner
# r-bio3d
# superlance
# jcc
# r-mcpan
# pyshp
# imglyb
# gevent
# ticcutils
# ulmo
# pytest-base-url
# pytest-regressions
# r-bb
# python-json-logger
# reprounzip-qt
# msumastro
# twisted
# xorg-libpthread-stubs
# pyemd
# r-autoshiny
# utm
# pygrametl
# f90wrap
# profimp
# pandas-gbq
# trottersuzuki
# go-gox
# r-assertthat
# lua
# r-tsibble
# django-reversion
# django-makemessages-xgettext
# r-lpsolveapi
# poppler
# cotire
# interpolation
# go-glide
# pytest-doctestplus
# bootstrap
# pypandoc
# r-dimred
# cfgrib
# trafaret
# asks
# flake8-blind-except
# larrayenv
# r-sgeostat
# jmol
# r-classint
# r-locfit
# r-rmpi
# r-ranger
# fdb
# molvs
# gspread
# r-gridbase
# espei
# r-abind
# opentracing_instrumentation
# gst-plugins-base
# cni-plugins
# unyt
# immutables
# django-cruds-adminlte
# terraform-provider-ultradns
# flask-admin
# docrep
# biopython
# segno
# entrypoints
# assimulo
# r-rniftyreg
# cgsn_parsers
# docutils
# r-snow
# genutil
# flask-silk
# fs-s3fs
# aionotify
# pweave
# sporco
# biopandas
# ginga
# otlm
# yamlloader
# sphinx-gallery
# aniso8601
# r-rcdk
# tabulator-py
# r-rnetcdf
# r-sciplot
# rotamerconvolvemd
# libcxxwrap-julia
# r-urltools
# pbzip2
# engarde
# radon
# bullet
# sdl2_gfx
# ligo-raven
# mpl-scatter-density
# faunus
# gammapy
# r-norm
# pretend
# sarge
# gwpy
# r-mapproj
# sos
# typogrify
# sox
# ukpostcodeparser
# myproxyclient
# libedit
# rasterstats
# r-hashmap
# sugartex
# svglib
# s3transfer
# poppler-data
# django-storages-redux
# r-ggm
# arm_pyart
# pyld
# flaky
# r-liblinear
# r-rstan
# r-multcomp
# r-snakecase
# affine
# udatetime
# r-bigrquery
# sphinxtesters
# pyopcode
# pika
# r-rocr
# bob.db.wine
# pytest
# r-pbkrtest
# xenon
# flask-celery-helper
# hypothesis
# dictdiffer
# pyyaml
# flask-turbolinks
# r-bigmemory
# terraform-provider-azurerm
# inotify-tools
# mysql-connector-c
# r-forcats
# r-registry
# flask-excel
# academic
# doconce
# orca
# r-permute
# boost
# python-blosc
# jaraco.logging
# r-ggplotify
# ipython_genutils
# tornado-sqlalchemy
# boto
# xrft
# pcl
# r-rbokeh
# pytest-spec
# cis_interface
# r-prediction
# django-rq
# sphinxcontrib-apidoc
# squashfs-tools
# jsonpickle
# ldap3
# jsmin
# reikna
# hunspell
# xorg-util-macros
# argtable2
# netcdf-cxx4
# homura
# r-th.data
# simpervisor
# sdl2_net
# astunparse
# ligo-segments
# wfastcgi
# r-ggfortify
# pyaml
# pyiron
# pykrige
# hdbscan
# r-pkgdown
# gala
# plio
# r-r.cache
# smif
# r-dorng
# xtl
# r-mumin
# jonga
# netcdftime
# r-wheatmap
# libgcrypt
# pimsviewer
# gulpio
# r-rotl
# pyreadstat
# r-ggalluvial
# xhtml2pdf
# javaobj-py3
# r-pheatmap
# r-gbrd
# overrides
# mcerp
# python-gnupg
# loompy
# sphinx-autobuild
# r-bcrocsurface
# brial
# xpdconf
# stuf
# pyemojify
# cdat-lite
# fastcluster
# xorg-libxext
# msgpack-c
# r-network
# speechrecognition
# storefact
# python-crontab
# r-genkern
# pytrie
# casacore
# r-ggpage
# r-alluvial
# calculix
# opbeat
# r-htmlwidgets
# murphy
# autoconf
# ...
# r-rsvd
# cligj
# xorg-videoproto
# r-vcd
# modestpy
# geoalchemy2
# r-jmv
# zipfile36
# r-glasso
# cmrt
# sudospawner
# python-ligo-lw
# glew
# pyscaffold
# spectrum
# terraform-provider-oneandone
# r-brew
# terraform-provider-cloudscale
# mechanicalsoup
# alps
# conda-pack
# fortranformat
# pytest-testmon
# stateplane
# r-oompabase
# r-blockmodeling
# cc-plugin-glider
# cc-plugin-ugrid
# odm2api
# ndg-httpsclient
# r-robustrankaggreg
# dose
# r-huxtable
# r-intergraph
# r-sna
# patool
# r-matlab
# louvain
# sphinxjp.themecore
# python-mimeparse
# subprocess32
# numdifftools
# xarray-topo
# r-testit
# r-picante
# jupyter-dashboards-server
# bottleneck
# django-unique-upload
# postgis
# typed-ast
# singularity
# r-foreign
# r-gridsvg
# aggdraw
# fann2
# trio
# yarn-api-client
# r-cli
# r-kriging
# fiona
# coreapi-cli
# opsdroid
# r-rphylip
# npstreams
# pooch
# msrestazure
# root
# r-zoo
# libva-utils
# watchdog-gevent
# libcdms
# google-cloud-storage
# r-cba
# r-pillar
# periodictable
# sphinxcontrib-programoutput
# importlib_metadata
# r-kerasformula
# pycron
# pamela
# gpy
# extinction
# murmurhash
# guidata
# libev
# r-questionr
# r-truncnorm
# venv-pack
# xtensor-python
# r-rapport
# desdeo-vis
# r-pamr
# mongo-tools
# logzero
# ocw
# r-filematrix
# python-dotenv
# r-moments
# mumps
# qt5reactor
# ipykernel
# r-matrix
# r-tree
# r-c3net
# jsonextended
# r-codetools
# wsgiproxy2
# pynwb
# r-rjags
# ggobi
# r-rjava
# azure-storage
# colour
# r-misc3d
# pyathena
# r-ismev
# geomalgo
# maxima
# r-withr
# markdown
# empyrical
# potranslator
# python-openid
# tyssue
# openimageio
# ipypublish
# pyomo.solvers
# pandoctools
# r-rafalib
# ndiff
# nbpresent
# artview
# pelican
# r-workflowr
# pybase64
# topika
# r-eulerr
# canmatrix
# nose-progressive
# r-stabledist
# r-bindrcpp
# r-factominer
# sqlalchemy-utc
# r-dppackage
# hips
# ppci
# hy
# pytest-mccabe
# r-rpmm
# chemfiles
# graphite2
# go-archiver
# r-klar
# r-rcolorbrewer
# sound_field_analysis
# ticcltools
# r-askpass
# apscheduler
# r-ggally
# retype
# jsonfield
# lrcalc
# r-clustercrit
# pybinding
# asciimatics
# fluidsynth
# r-rosm
# marshmallow
# amptools
# traittypes
# cem
# r-smoothwin
# vmd-python
# cybuffer
# soappy
# r-distutils
# backports.os
# r-bezier
# argcomplete
# r-taxize
# lalapps
# r-ffield
# r-labeling
# tskit
# gperftools
# r-strucchange
# nbstripout
# macholib
# holidays
# tvb-gdist
# imreg_dft
# r-extrafontdb
# delocate
# etcd
# w3m
# r-bh
# cleo
# terraform-provider-postgresql
# tabulatehelper
# r-covr
# pygrib
# xframe
# grunt
# cppzmq
# pyfolio
# grin
# ntlm-auth
# wikipedia
# netaddr
# osqp
# texinfo
# yaafe
# dateutils
# squash
# pyfive
# r-seriation
# jupyter-server-proxy
# r-treemapify
# thinkx
# tini
# pyfim
# r-mlmetrics
# r-later
# r-flexmix
# r-viridis
# r-waveslim
# r-fbasics
# psycopg2
# pyiron_example_job
# terraform-provider-spotinst
# r-regress
# conda-ecosystem-user-package-isolation
# azure-mgmt-common
# gridstack.js
# cdo
# r-fcros
# terraform-provider-rabbitmq
# xorg-imake
# repeated_test
# r-effects
# r-spls
# funcsigs
# azure-mgmt-keyvault
# r-assertive.models
# r-lokern
# packaging
# r-bit
# zstd
# yarg
# pyjanitor
# zn_poly
# r-pander
# deprecation
# plumbum
# r-sm
# r-esquisse
# python-coreschema
# nose-cov
# r-tfestimators
# cli_helpers
# pvlib-python
# regions
# pytest-flask
# nose_parameterized
# deprecated
# positional
# mr.bob
# xorg-xf86vidmodeproto
# pandas
# photutils
# chartify
# virtualenv-clone
# r-skmeans
# tiledb
# r-fivethirtyeight
# rickshaw
# linbox
# consul-template
# python-nvd3
# pyqi
# latexcodec
# thredds_crawler
# r-leaflet
# pyflann
# yacron
# rt1
# r-ordinal
# locust
# weave
# yasm
# r-rms
# r-xml
# bob.measure
# py
# eli5
# cgen
# r-nozzle.r1
# gnuplot
# flask-debugtoolbar
# fastdtw
# lml
# traitsui
# dotmap
# wheel
# r-pkgconfig
# jsdom
# agate-excel
# vounwarp
# easywatch
# hcephes
# xorg-gccmakedep
# r-upsetr
# geographiclib
# r-extradistr
# aplus
# snaptime
# terraform-provider-softlayer
# pytest-json
# sympow
# telluric
# r-rweka
# tsl_hopscotch_map
# r-amap
# pydash
# autowrap
# westpa
# bintrees
# r-nlp
# cunit
# r-evaluate
# yq
# r-preseqr
# sniffio
# django-cors-headers
# usagestats
# buildpy
# xfig
# nbfinder
# r-gdtools
# r-perm
# pytest-shutil
# maltpynt
# stomp.py
# iowait
# tableschema-py
# gdk-pixbuf
# pcre2
# r-qtl
# ratpoints
# spefile
# sphinx-bootstrap-theme
# iminuit
# r-iterators
# clamd
# ogh
# r-modelmetrics
# r-rstantools
# nss
# lalxml
# nitro
# msrest
# pycrypto
# flask-oldsessions
# r-r.huge
# r-skynet
# python-levenshtein
# r-ggvis
# matplotlib2tikz
# python-couchdb
# libdrs_f
# r-bit64
# r-slim
# imgroi
# steemdata
# r-rebus.datetimes
# r-servr
# fabric3
# metaphone
# r-gganimate
# r-tkrplot
# websockets
# locket
# spglm
# cheat
# primesieve
# django-redis-cache
# freeglut
# hmmlearn
# snzip
# r-rpf
# simage
# kubernetes
# sqlacodegen
# r-ccp
# sphinxcontrib-golangdomain
# esmlab
# simplegeneric
# pydy
# wxnatpy
# r-argparser
# tqdm
# rollbar
# pivottable
# mkdocs
# datadog
# bashplotlib
# poyo
# fpyutils
# kiwipy
# r-shadowtext
# r-pspearman
# r-runit
# nbsmoke
# pyxley
# spectra
# yappi
# librdkafka
# aiohttp
# fortran-magic
# update_checker
# r-tmvtnorm
# linear-tsv
# r-laeken
# cssmin
# r-tidymodels
# pytest-fixture-config
# zopfli
# psy-strat
# r-capushe
# hveto
# r-heatmaply
# calamari_ocr
# nsis
# pylems
# r-deldir
# r-ssanv
# lastools
# timeout-decorator
# r-objectsignals
# r-rpostgresql
# r-smoother
# intake-avro
# marbles-mixins
# cyordereddict
# nlohmann_json
# pdblp
# django-pkgconf
# py_stringmatching
# djangorestframework-xml
# django-redis
# pyxid
# pandas-summary
# sparkmagic
# terraform-provider-alicloud
# visitor
# deeplearnjs
# autopep8
# hpack
# identify
# chemfiles-lib
# amqp
# judy
# sip
# block_tracing
# r-gee
# sncosmo
# litereval
# betsee
# celerite
# r-lavaan
# r-entropy
# r-mass
# async_timeout
# r-heatmap.plus
# category_encoders
# fossil
# unicodedata2
# r-biwt
# pymeep
# erlang
# nltk_data
# r-ic.infer
# hyperopt
# healpix_cxx
# r-labdsv
# r-weatherdata
# pyvirtualdisplay
# python-coreapi
# uncertainties
# cryptopp
# black
# r-polycor
# backports.shutil_which
# lazyasd
# deepdish
# pyne
# python-eccodes
# pybind11
# sparsehash
# flask-assets
# cyberpandas
# terraform-provider-aws
# ez_setup
# r-grf
# r-tergm
# passlib
# python-louvain
# conda-forge-pinning
# easyargs
# r-textshape
# r-landscapemetrics
# parameterized
# r-rwekajars
# ligo-scald
# r-urca
# terraform-provider-openstack
# apsg
# iperf
# openmotif
# r-spatial
# rdflib-jsonld
# gnupg
# slang
# openpiv
# clapack
# material-design-lite
# r-tidytext
# slugify
# jupyter_kernel_test
# pytest-django
# latexmk
# cpulimit
# r-ibd
# r-beeswarm
# pyvisfile
# vsts-python-api
# r-exactranktests
# r-survival
# peewee
# liblbfgs
# scons
# construct
# r-grplasso
# pyscreeze
# xorg-libxcursor
# r-vegan
# r-timeroc
# r-tensr
# r-hdf5r
# fuzzywuzzy
# smesh
# lzip
# py-mathjax
# spacy-model-en_core_web
# cymem
# dateparser
# omnifit
# python-ecmwf_grib
# p11-kit
# r-dmwr
# r-curl
# cdat_info
# r-dbi
# qcportal
# pathspec
# r-meta
# libtasn1
# django-pandas
# glue-core
# r-rmysql
# r-irr
# libint
# r-natserv
# d2to1
# r-plasmidprofiler
# nb_conda_kernels
# limix-core
# geolinks
# r-boot
# r-powerlaw
# geotiff
# r-openxlsx
# datashader
# pytest-django-haystack
# r-tufte
# orch
# r-rprojroot
# r-pryr
# hyperion-fortran
# pypy3.5
# r-biocmanager
# monotonic
# pyregion
# ocaml-camlp5
# r-iml
# reaper
# r-callr
# r-sdmtools
# feedgenerator
# ncephes
# r-sqn
# r-getoptlong
# pyorgmode
# pysendfile
# setuptools
# datashape
# lmfit
# timezonefinder
# r-clue
# azure
# flask-babelex
# r-maptree
# adept
# clfft
# bison
# lscsoft-glue
# r-findpython
# r-ggsci
# r-extremevalues
# pymysql
# r-httpcode
# vaex-arrow
# kneed
# psiturk
# ctags
# go-bindata
# r-import
# r-nnlasso
# r-multiroc
# dsub
# r-randtoolbox
# cycamore
# pydispatcher
# r-rje
# djangocms-admin-style
# pympler
# r-taxizesoap
# pycryptodome
# pycoal
# pydensecrf
# osfclient
# handlebars.js
# terraform-provider-dme
# defusedxml
# libmed
# jftools
# python-socketio
# r-varhandle
# r-fontbitstreamvera
# automake
# wsaccel
# sqlitedict
# htop
# pyhdb
# smmap2
# pypdf2
# containerpilot
# astroid
# alembic
# r-gmp
# superlu
# pytest-runner
# flask-creole
# sigopt
# chalk
# r-quantmod
# r-bayesplot
# lemon
# r-ctv
# parmetis
# wxpython
# threedigrid
# pyicu
# r-checkpoint
# pymumps
# r-hwriter
# cryptography-vectors
# traitlets
# pypy2.7
# gridutils
# urbansim_templates
# ruamel.ordereddict
# qtconsole
# mpl-probscale
# cx_freeze
# flask-nav
# python-telegram-bot
# r-lsmeans
# properties
# r-blme
# nose2
# r-apcluster
# r-objectproperties
# gwdetchar
# python-pdal
# libflint
# fabric
# check-manifest
# scikit-surprise
# r-discriminer
# r-syuzhet
# r-collapsibletree
# r-fma
# bob.extension
# r-filesstrings
# tatsu
# pdfminer3k
# async_generator
# r-castor
# prompt
# r-nlme
# jupyter-themer
# flask-cache
# pytest-aiohttp
# historydict
# r-robcompositions
# jellyfish
# pandoc
# jsoncpp
# fs.webdavfs
# threadloop
# nb_conda
# huey
# sagemath-db-combinatorial-designs
# pymiescatt
# r-superheat
# xorg-xcb-proto
# planet
# r-randtests
# verboselogs
# r-cellranger
# roslibpy
# circleclient
# fixie-data
# txmongo
# fermipy
# wicken
# ipyvolume
# pymbar
# r-trimcluster
# r-compositions
# easydict
# termcolor
# fasteners
# pyedflib
# python-lzo
# r-future.apply
# galpy
# heapdict
# compas
# r-expm
# r-ruv
# esmp
# openorb-data
# awscli
# ninja
# ilmbase
# r-essentials
# wntr
# r-widyr
# xwebrtc
# mrjob
# verde
# unicodecsv
# popt
# google-resumable-media
# pugixml
# pycparser
# scikit-build
# pykep
# r-diffusionmap
# blas
# vs2008_express_vc_python_patch
# r-gamm4
# backports.unittest_mock
# reprozip
# hyperion
# django-recaptcha
# r-gss
# jedi
# pytest-cpp
# r-mosaicdata
# dask-mpi
# django-admin-shortcuts
# scikit-mdr
# websocket-client
# r-fselector
# robotframework
# r-mlogit
# r-extrafont
# r-leaps
# recommonmark
# animatplot
# aws-xray-sdk
# krb5
# r-base64url
# pydocstyle
# delegator
# descarteslabs
# moviepy
# flask-security
# xonsh
# fisher
# copulae
# gnupg-py
# r-foreach
# arrow-cpp
# win_inet_pton
# r-knitr
# r-nada
# r-rgcca
# r-remotes
# otpmml
# webargs
# r-shinylp
# tomopy
# qt
# ukcensusapi
# r-ddalpha
# r-optimx
# r-rdrop2
# pmda
# r-splus2r
# r-extremes
# collectfast
# r-rhpcblasctl
# sympy
# h5netcdf
# r-ecp
# asyncpg
# spyne
# r-tangram
# doepipeline
# r-partykit
# r-groupedstats
# libdiffpy
# python-graphviz
# r-adehabitatma
# flask-babel
# knit
# r-writexls
# colorcet
# accimage
# r-assotester
# azure-graphrbac
# pytest-lazy-fixture
# thrift
# arxiv-collector
# biom-format
# automat
# r-numderiv
# cymetric
# freud
# nbsphinx
# terraform-provider-cobbler
# jieba3k
# siphon
# bloscpack
# fs_filepicker
# r-tester
# r-rpart
# msprime
# r-rodbc
# pexpect
# wcslib
# pastas
# sdsl-lite
# bson
# ansible
# betfairlightweight
# r-ggmcmc
# fixie-batch
# pytest-html
# pymt_sedflux
# esutil
# python-leveldb
# datarobot
# kombu
# python-oauth2
# flask-moment
# flex-swagger
# js-cookie
# pyopengl
# r-gower
# httplib2
# r-lsd
# r-echarts4r
# functools32
# r-rfutilities
# modernize
# flask-testing
# rapidz
# r-keyring
# openlibm
# yapsy
# paegan-transport
# earthengine-api
# pyretis
# fs
# r-factoextra
# mutagen
# r-batch
# cfchecker
# dask-memusage
# nltk
# r-sampling
# ffnvcodec-headers
# dask-ndfilters
# sqlalchemy
# r-pool
# pytrilinos
# ejplugins
# hub
# cliquer
# r-recipes
# discretizer
# r-prodlim
# r-sparsesvd
# r-mqtl
# r-lattice
# iris
# mocsy
# pydot
# r-listenv
# ijson
# hyperlink
# r-fs
# r-flexdashboard
# qhull
# siesta
# pycosat
# sagemath-db-conway-polynomials
# ezodf
# pydstool
# r-hash
# libidn2
# cogapp
# grequests
# codecov
# text-unidecode
# gtk2
# zarr
# structlog
# r-distr
# xorg-compositeproto
# r-geomap
# blpapi
# parabem
# jupytext
# r-debugme
# ufal.udpipe
# r-htmlutils
# vsc-install
# pygobject
# zwatershed
# urlobject
# dash-renderer
# flask-markdown
# backports.lzma
# r-vipor
# r-prabclus
# tableschema
# dlib
# fletcher
# pydl
# cspice
# portend
# aplpy
# cerberus
# omas
# r-future
# labjackpython
# python-node-semver
# pluggy
# texlive-core
# r-evd
# voluptuous
# graphene
# perl-sys-cpu
# python-gflags
# r-contfrac
# jupyter_client
# cclib
# qpdf
# vcrpy
# r-assertive.data.uk
# spacy
# mdanalysistests
# scandir
# multidict
# ldap
# pixstem
# holoviews
# r-glmmtmb
# pipfile
# mpiplus
# green
# r-docxtools
# qtawesome
# numpy
# pkginfo
# sqlalchemy-migrate
# certifi
# gmt
# r-pkgload
# geckodriver
# otsubsetinverse
# flask-openid
# r-nortest
# r-gstat
# pandocfilters
# cw-eval
# python-pptx
# r-isocodes
# r-mlmrev
# bash
# ipywebrtc
# nbexamples
# r-bnlearn
# mingwpy
# filelock
# rank_filter
# clifford
# specutils
# r-plot3drgl
# r-rcppnumerical
# xtensor-io
# googletrans
# smart_open
# ferret_datasets
# babel
# tcsh
# lalpulsar
# r-psychotools
# dill
# r-clusterr
# jsontableschema
# r-verification
# r-splancs
# mapkit
# pytest-asyncio
# lodash
# colorlover
# whoosh
# pykdtree
# r-tidygraph
# pyexcel-ods3
# bob.ip.color
# oktopus
# fastcache
# tablib
# nasm
# camb
# r-rebus.base
# hpc05
# codes-ui
# r-aroma.apd
# r-rpmg
# ws4py
# r-acepack
# r-parallelmap
# uritools
# terraform-provider-terraform
# r-fracdiff
# os-client-config
# geocoder
# htmlmin
# python-geotiepoints
# robobrowser
# seqan-library
# r-ggplot2
# go-dep
# ablog
# r-readr
# invoke
# more.forwarded
# mppp
# r-timeseries
# sphinxcontrib-versioning
# r-icsnp
# r-wmtsa
# pydap
# pythonqwt
# requirements-parser
# xorg-libice
# datamountaineer-schemaregistry
# r-flexclust
# r-ggbeeswarm
# imbalanced-learn
# pyepics
# hydrostats
# r-tilegramsr
# chai
# conda-build
# xtensor
# r
# gobject-introspection
# iverilog
# hachoir-parser
# elektronn
# openorb-data-de405
# mlpack
# msgpack-numpy
# praw
# backward-cpp
# channelarchiver
# stem
# cvxopt
# flake8-pep3101
# r-fdrtool
# r-cairodevice
# r-gghighlight
# mlconjug
# asyncssh
# sqlparse
# pysgrid
# r-als
# r-linkcomm
# help2man
# metis
# ca-certificates
# python-ternary
# pysbatch
# r-params
# click-spinner
# r-colorramps
# gperf
# r-gsmoothr
# r-earth
# wrighttools
# r-networkd3
# iml
# scikit-optimize
# qt_style_sheet_inspector
# nptdms
# pymt_permamodel
# pytest-timeout
# r-mpmi
# cyclus
# cherrypy
# eigen
# r-git2r
# hvplot
# wgrib2
# social-auth-core
# binutils
# r-cubist
# r-ccdralgorithm
# lmdb
# atdict
# tempora
# celery-singleton
# r-rsconnect
# liknorm
# conllu
# r-colourpicker
# vipaccess
# grave
# cling-patches
# patch
# r-penalized
# xeus-python
# cyrus-sasl
# onnx-caffe2
# markdown2
# pims
# glue-vispy-viewers
# r-pbs
# pyaudi
# r-nbclust
# django-autoslug
# datamash
# terraform-provider-cloudstack
# zodburi
# r-aws.s3
# icu
# pyspark
# orange3-timeseries
# libmo_unpack
# datatables
# elastic
# pygmo_plugins_nonfree
# r-shinytree
# r-cyclocomp
# r-openimager
# bob.ip.base
# python-decouple
# dectate
# celery-eternal
# graph
# sputnik
# kernda
# r-chemometricswithr
# python-awips
# qrcode
# lap
# nc_time_axis
# bob.ap
# fissix
# pygmo
# neotime
# av
# r-cairo
# r-shiny
# pint
# zstandard
# mpas-analysis
# r-markovchain
# sdf
# imagemagick
# beakerx
# r-rknn
# r-sessioninfo
# pyscss
# r-tweenr
# frozen-flask
# heudiconv
# ghc
# mkl_random
# r-shades
# cdtime
# rcssmin
# xtensor-r
# r-mapplots
# scikit-garden
# pandoc-attributes
# r-pbapply
# graphql-core
# r-class
# httptools
# pytest-tornado
# python-pegasus-wms
# coreutils
# swiglpk
# llvmlite
# sherlockml-dataclean
# highfive
# markdown_strings
# r-rtsne
# llvm-meta
# bob.learn.boosting
# autodiff
# python
# pthreads-win32
# requests_cache
# r-styler
# r-anom
# lynx
# r-survivalroc
# srtm.py
# msgpack-python
# r-vim
# ixmp
# gql
# flit
# jsonpatch
# pycroscopy
# climlab
# r-dichromat
# eight
# nfft
# r-topicmodels
# r-oriclust
# jupyter_enterprise_gateway
# basemap-data-hires
# flask-socketio
# testpath
# requests-mock
# harminv
# cluster-lensing
# r-fields
# robotframework-lint
# seccomp-split
# python-spams
# ligo.skymap
# r-vbsr
# coolprop
# py-lz4framed
# lightgbm
# testfixtures
# clhep
# django-grappelli
# pytest-cache
# r-randomforest
# click-default-group
# astroquery
# r-tidybayes
# glob2
# gsshapy
# assetid
# bob.learn.em
# r-ergm
# exercism
# hdfeos5
# r-bfa
# pytest-regtest
# ratelimiter
# otpod
# spacy-model-nl
# r-ccremover
# bqplot
# r-statnet.common
# aspy.yaml
# blosc-hdf5-plugin
# landlab
# r-psych
# nds2-client-swig
# pyopencl
# fdupes
# r-rgooglemaps
# r-bbmle
# r-automap
# r-xtensor
# aiopeewee
# docopt
# r-unireg
# pyqt
# pyunfold
# r-nycflights13
# r-xml2
# kastore
# r-mapdata
# asciitree
# ssl_match_hostname
# flask-compress
# deepdiff
# tinycss2
# spylon
# google-auth-oauthlib
# r-ggparallel
# pytest-cov
# pyusid
# r-longitudinal
# f90nml
# ipyevents
# progressbar2
# protobuf
# cloudant
# r-vars
# glibmm
# events
# byobu
# windspharm
# bicycleparameters
# pyfai
# warlock
# pyemma
# docstring-coverage
# optlang
# pyexcel-xls
# pyemma_tutorials
# ipynb-py-convert
# poliastro
# xorg-presentproto
# r-ontologyindex
# python-flatbuffers
# ntbtls
# rpfits
# inspyred
# django-widget-tweaks
# xorg-cf-files
# fribidi
# parso
# tiledb-py
# nbval
# multiprocess
# ipycache
# psy-maps
# pytest-remotedata
# leveldb
# r-profilemodel
# django-bootstrap4
# r-robis
# r-quantreg
# fontconfig
# dummydata
# ciso
# xorg-applewmproto
# easybuild
# r-ahocorasicktrie
# nearpy
# munch
# pyexcel-io
# r-recommended
# ads
# metsim
# r-bbmisc
# xlwings
# recursive_diff
# cyipopt
# scyjava
# django-rest-auth
# r-ggnetwork
# gidgethub
# r-flashclust
# rx
# billiard
# r-cdft
# newt
# r-tictoc
# r-spacetime
# powerline-status
# poco
# asttokens
# libmad
# rubiks
# lektor
# diskcache
# spark-testing-base
# fancycompleter
# flock
# flask-flatpages
# r-pixmap
# gosu
# caffe
# r-modes
# optimix
# r-pec
# pescador
# r-biglm
# ctd
# micromagneticmodel
# r-sparql
# re2
# r-graphtweets
# grpc-cpp
# r-assertive.numbers
# lbzip2
# nodejs
# django-mptt
# pydda
# flake8-import-order
# geoalchemy-odm2
# r-log4r
# h5utils
# python-ldap
# terraform-provider-opentelekomcloud
# r-skellam
# mdshare
# dask-xgboost
# r-validate
# humanfriendly
# r-whisker
# wkhtmltopdf
# rxcpp
# qcodes
# sqlalchemy-redshift
# pyinstrument
# pyct-core
# r-quanteda
# macfsevents
# r-dt
# r-xlconnect
# intake-sql
# r-gtable
# cc-plugin-ncei
# flake8-copyright
# r-spatstat.utils
# sphinxcontrib-paverutils
# r-propcis
# furl
# snoopy-log-collator
# r-satellite
# poetry
# nibabel
# ansiwrap
# libitk
# openjdk
# r-rchoicedialogs
# xorg-fontsproto
# r-plotmo
# pyavm
# zope.deprecation
# flask-jwt-extended
# r-yardstick
# cycler
# r-ggconf
# r-operator.tools
# turbodbc
# existdb
# git-lfs
# r-manipulatewidget
# pykriging
# quart-openapi
# r-mbess
# skein
# vaex-server
# pandas-msgpack
# ad3-cpp
# backpack
# bitarray
# jsontableschema-pandas
# coq
# intltool
# r-broom
# r-solarius
# desdeo
# vaex-distributed
# r-metafor
# xorg-libxi
# ossuuid
# django-modelcluster
# contextvars
# odvc
# orderedmultidict
# odm2rest
# distarray
# r-party

# %% [markdown]
# ## Compare conda-forge feedstocks to packages that Anaconda is missing from the top 1000K PyPI packages

# %%
cf_pkg_diff = pypi_pkgs.difference(feedstocks)
print("Number of conda-forge pkgs that Anaconda lacks from pypi top 1K: {}\n".format(len(cf_pkg_diff)))
cf_diff_sorted = sorted(cf_pkg_diff)
for cf_pkg in cf_diff_sorted:
    print(cf_pkg)
# Out:
# Number of conda-forge pkgs that Anaconda lacks from pypi top 1K: 340
#
# acme
# analytics-python
# antlr4-python3-runtime
# aspy-yaml
# awsebcli
# azure-batch
# azure-cli-acr
# azure-cli-acs
# azure-cli-advisor
# azure-cli-appservice
# azure-cli-backup
# azure-cli-batch
# azure-cli-batchai
# azure-cli-billing
# azure-cli-cdn
# azure-cli-cloud
# azure-cli-cognitiveservices
# azure-cli-command-modules-nspkg
# azure-cli-configure
# azure-cli-consumption
# azure-cli-container
# azure-cli-cosmosdb
# azure-cli-dla
# azure-cli-dls
# azure-cli-eventgrid
# azure-cli-extension
# azure-cli-feedback
# azure-cli-find
# azure-cli-interactive
# azure-cli-iot
# azure-cli-keyvault
# azure-cli-lab
# azure-cli-monitor
# azure-cli-network
# azure-cli-nspkg
# azure-cli-profile
# azure-cli-rdbms
# azure-cli-redis
# azure-cli-reservations
# azure-cli-resource
# azure-cli-role
# azure-cli-servicefabric
# azure-cli-sql
# azure-cli-storage
# azure-cli-vm
# azure-cosmosdb-nspkg
# azure-cosmosdb-table
# azure-datalake-store
# azure-eventgrid
# azure-mgmt-advisor
# azure-mgmt-applicationinsights
# azure-mgmt-batch
# azure-mgmt-batchai
# azure-mgmt-billing
# azure-mgmt-cdn
# azure-mgmt-cognitiveservices
# azure-mgmt-commerce
# azure-mgmt-consumption
# azure-mgmt-containerinstance
# azure-mgmt-containerregistry
# azure-mgmt-containerservice
# azure-mgmt-cosmosdb
# azure-mgmt-datafactory
# azure-mgmt-datalake-analytics
# azure-mgmt-datalake-nspkg
# azure-mgmt-datalake-store
# azure-mgmt-datamigration
# azure-mgmt-devtestlabs
# azure-mgmt-dns
# azure-mgmt-eventgrid
# azure-mgmt-eventhub
# azure-mgmt-hanaonazure
# azure-mgmt-iotcentral
# azure-mgmt-iothub
# azure-mgmt-iothubprovisioningservices
# azure-mgmt-loganalytics
# azure-mgmt-logic
# azure-mgmt-machinelearningcompute
# azure-mgmt-managementgroups
# azure-mgmt-managementpartner
# azure-mgmt-maps
# azure-mgmt-marketplaceordering
# azure-mgmt-media
# azure-mgmt-monitor
# azure-mgmt-notificationhubs
# azure-mgmt-policyinsights
# azure-mgmt-powerbiembedded
# azure-mgmt-rdbms
# azure-mgmt-recoveryservices
# azure-mgmt-recoveryservicesbackup
# azure-mgmt-redis
# azure-mgmt-relay
# azure-mgmt-reservations
# azure-mgmt-scheduler
# azure-mgmt-search
# azure-mgmt-servicebus
# azure-mgmt-servicefabric
# azure-mgmt-signalr
# azure-mgmt-sql
# azure-mgmt-subscription
# azure-mgmt-trafficmanager
# azure-mgmt-web
# azure-multiapi-storage
# azure-servicefabric
# backports-abc
# backports-csv
# backports-functools-lru-cache
# backports-shutil-get-terminal-size
# backports-ssl-match-hostname
# backports-tempfile
# backports-weakref
# bandit
# baselines
# beautifulsoup
# blessed
# brunel
# bs4
# capstone
# certbot
# certbot-apache
# certbot-nginx
# cfn-flip
# cheetah
# collections-extended
# confluent-kafka
# cookiejar
# coreapi
# coreschema
# cx-oracle
# databricks-cli
# datetime
# ddtrace
# discord-py
# django-compressor
# django-ipware
# django-rest-swagger
# docker
# dogpile-cache
# ec2-metadata
# elasticsearch-curator
# enum
# et-xmlfile
# expiringdict
# factory-boy
# fakeredis
# feedparser
# gapic-google-cloud-datastore-v1
# gapic-google-cloud-error-reporting-v1beta1
# gapic-google-cloud-logging-v2
# gapic-google-cloud-pubsub-v1
# gcloud
# gdata
# geoip2
# google-apitools
# google-cloud
# google-cloud-bigquery-datatransfer
# google-cloud-bigtable
# google-cloud-container
# google-cloud-dataflow
# google-cloud-datastore
# google-cloud-dns
# google-cloud-error-reporting
# google-cloud-firestore
# google-cloud-language
# google-cloud-logging
# google-cloud-pubsub
# google-cloud-resource-manager
# google-cloud-runtimeconfig
# google-cloud-spanner
# google-cloud-speech
# google-cloud-trace
# google-cloud-translate
# google-cloud-videointelligence
# google-cloud-vision
# google-compute-engine
# google-gax
# googleads
# googledatastore
# grpc-google-iam-v1
# grpcio-tools
# gym
# hacking
# hashids
# hdfs
# html2text
# hvac
# idna-ssl
# influxdb
# initools
# intel-openmp
# ipython-genutils
# jaraco-functools
# josepy
# jsonpath-rw
# jupyter-client
# jupyter-console
# jupyter-core
# jws
# letsencrypt
# libtmux
# logging
# manhole
# maxminddb
# meld3
# mkl
# mleap
# mlflow
# mozfile
# mozinfo
# mozlog
# mozprofile
# mozrunner
# mozterm
# msgpack
# multi-key-dict
# mypy-extensions
# mysql-connector
# mysql-python
# nose-exclude
# nvidia-ml-py3
# oauth
# oauth2
# openapi-codec
# opencv-python
# osc-lib
# oslo-concurrency
# oslo-config
# oslo-context
# oslo-i18n
# oslo-log
# oslo-serialization
# oslo-utils
# package
# pager
# paho-mqtt
# parse-type
# parsel
# path-py
# pattern
# pg8000
# pip-lock
# pip-tools
# pipenv
# pre-commit
# prometheus-client
# prompt-toolkit
# proto-google-cloud-datastore-v1
# proto-google-cloud-error-reporting-v1beta1
# proto-google-cloud-logging-v2
# proto-google-cloud-pubsub-v1
# protobuf3-to-dict
# psycopg2-binary
# pyathenajdbc
# pycountry-convert
# pycurl
# pydevd
# pydocumentdb
# pygame
# pygsheets
# pyhive
# pykube
# pylru
# pynamodb
# pypiwin32
# pypng
# pyqt5
# pyrfc3339
# pysqlite
# pytest-instafail
# python-augeas
# python-cinderclient
# python-consul
# python-geohash
# python-glanceclient
# python-http-client
# python-jwt
# python-keystoneclient
# python-logstash
# python-nmap
# python-novaclient
# python-openstackclient
# python-pam
# python-subunit
# python-swiftclient
# pythonwhois
# pyvmomi
# querystring-parser
# queuelib
# readme-renderer
# redis
# redis-py-cluster
# repoze-lru
# requests-aws4auth
# requests-file
# requests-ntlm
# retry
# ruamel-ordereddict
# ruamel-yaml
# s2sphere
# schedule
# schema
# semantic-version
# service-identity
# simpleflock
# sklearn
# slackweb
# smart-open
# spark-sklearn
# sphinx-rtd-theme
# stripe
# suds
# tensorflow-gpu
# tensorflow-metadata
# tensorflow-tensorboard
# tensorflow-transform
# thrift-sasl
# torch
# troposphere
# trueskill
# twilio
# typing-extensions
# unittest-xml-reporting
# uptime
# uuid
# validate-email
# virtualenvwrapper
# vsts-cd-manager
# w3lib
# wandb
# weasyprint
# webapp2
# webtest
# win-inet-pton
# wordsegment
# zc-lockfile
# zmq
# zope-component
# zope-deprecation
# zope-event
# zope-interface
